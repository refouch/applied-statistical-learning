# %%
# %conda create -n xgb-gpu python=3.10
#%conda activate xgb-gpu
#%conda install -c conda-forge py-xgboost-gpu
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 get_ipython().run_line_magic('conda', 'create -n xgb-gpu python=3.10')
#       2 #%conda activate xgb-gpu
#       3 #%conda install -c conda-forge py-xgboost-gpu
#
# File /opt/python/lib/python3.13/site-packages/IPython/core/interactiveshell.py:2511, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2509     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2510 with self.builtin_trap:
# -> 2511     result = fn(*args, **kwargs)
#    2513 # The code below prevents the output from being displayed
#    2514 # when using magics with decorator @output_can_be_silenced
#    2515 # when the last Python token in the expression is a ';'.
#    2516 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# ...

# %%
# %pip install -r requirements.txt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
from utils.load_data import fma_load

features = fma_load('data/fma_metadata/features.csv')

features

tracks = fma_load('data/fma_metadata/tracks.csv')

y = tracks['track','genre_top']

corr = features.corr()

threshold = 0.75

corr_matrix = corr.copy()

np.fill_diagonal(corr_matrix.values, 0) # Diagonal to zero

strong_corr = (corr_matrix.abs() > threshold)

pairs = []
for i in range(len(corr_matrix.columns)):
    for j in range(i+1, len(corr_matrix.columns)):
        if strong_corr.iloc[i, j]:
            pairs.append({
                "feature_1": corr_matrix.columns[i],
                "feature_2": corr_matrix.columns[j],
                "correlation": corr_matrix.iloc[i, j]
            })
pairs
# Out:
# [{'feature_1': ('chroma_cens', 'mean', '01'),
#   'feature_2': ('chroma_cens', 'median', '01'),
#   'correlation': np.float64(0.9717560508855922)},
#  {'feature_1': ('chroma_cens', 'mean', '01'),
#   'feature_2': ('chroma_cqt', 'mean', '01'),
#   'correlation': np.float64(0.9281310171436797)},
#  {'feature_1': ('chroma_cens', 'mean', '01'),
#   'feature_2': ('chroma_cqt', 'median', '01'),
#   'correlation': np.float64(0.9147936958742171)},
#  {'feature_1': ('chroma_cens', 'mean', '02'),
#   'feature_2': ('chroma_cens', 'median', '02'),
#   'correlation': np.float64(0.9710105562557106)},
#  {'feature_1': ('chroma_cens', 'mean', '02'),
#   'feature_2': ('chroma_cqt', 'mean', '02'),
#   'correlation': np.float64(0.8924722909612783)},
#  {'feature_1': ('chroma_cens', 'mean', '02'),
#   'feature_2': ('chroma_cqt', 'median', '02'),
#   'correlation': np.float64(0.891592107193247)},
#  {'feature_1': ('chroma_cens', 'mean', '02'),
#   'feature_2': ('chroma_cqt', 'skew', '02'),
# ...

# %%
features.drop(columns=['chroma_cqt','chroma_cens'],inplace=True)
features = features.loc[:, features.columns.get_level_values('statistics') != 'median']

features
# Out:
# feature    chroma_stft                                                    \
# statistics    kurtosis
# number              01        02        03        04        05        06
# track_id
# 2            -1.006041 -0.634076 -0.233752 -0.120917  0.004806  1.218982
# 3            -0.951502 -0.660734 -1.050015 -0.977441 -0.343043 -0.515404
# 5            -0.794551 -1.264806 -0.664387 -0.405196 -0.022688  0.014883
# 10            0.954931 -1.266404  0.030425 -0.646823  0.664217  0.082626
# 20           -0.048443 -0.543755 -1.336000 -0.410307 -0.684526 -0.960676
# ...                ...       ...       ...       ...       ...       ...
# 155316       -0.959207 -0.130793 -0.635587 -0.251981 -0.656534 -0.238574
# 155317       -0.965068 -0.679953 -1.051353 -0.852524 -0.872679 -0.740262
# 155318       -0.771414 -0.438261 -0.888968 -0.730804 -0.868208 -0.623147
# 155319       -0.984837 -0.198621 -0.923624 -0.825457 -1.035743 -0.919991
# ...

# %%
from collections import Counter

df_flat = features.copy()
df_flat.columns = ['_'.join(col).strip() for col in df_flat.columns.values]

df_flat['genre_top'] = y

df_flat.dropna(inplace=True)

counts = Counter(df_flat['genre_top'])

rare_classes = [cls for cls, c in counts.items() if c < 1000]

df_flat["genre_top_grouped"] = df_flat["genre_top"].replace(
    {cls: "Other" for cls in rare_classes}
)

df_flat
# Out:
#           chroma_stft_kurtosis_01  chroma_stft_kurtosis_02  \
# track_id
# 2                       -1.006041                -0.634076
# 3                       -0.951502                -0.660734
# 5                       -0.794551                -1.264806
# 10                       0.954931                -1.266404
# 134                     -0.972450                -1.047674
# ...                           ...                      ...
# 155315                  -0.931622                -0.823569
# 155316                  -0.959207                -0.130793
# 155317                  -0.965068                -0.679953
# 155318                  -0.771414                -0.438261
# 155319                  -0.984837                -0.198621
#
#           chroma_stft_kurtosis_03  chroma_stft_kurtosis_04  \
# track_id
# 2                       -0.233752                -0.120917
# 3                       -1.050015                -0.977441
# ...

# %%
#Retirer les chroma pour voir, change peu de choses
df_flat = df_flat.loc[:, ~df_flat.columns.str.startswith("chroma_stft_max")]

# %%
#garder 30 features pour voir
df_flat[top_features]
# Out:
#           tonnetz_skew_01  mfcc_std_19  tonnetz_min_04  mfcc_mean_15  \
# track_id
# 2                0.752462     7.077188       -0.140306      1.465213
# 3                0.265541     7.417791       -0.304375      0.274716
# 5                1.212025     8.452527       -0.166667      7.899487
# 10              -0.135219     6.430473       -0.343055     -4.099704
# 134              0.927807     7.134986       -0.328776      4.580719
# ...                   ...          ...             ...           ...
# 155315          -1.074692     6.055836       -0.215644      1.916379
# 155316          -0.453276     5.105072       -0.429963     -0.401464
# 155317          -0.490728     5.541949       -0.414251      1.503421
# 155318          -0.296828     5.685448       -0.375282     -0.148982
# 155319           0.007862     5.187994       -0.248391      2.012845
#
#           chroma_stft_skew_02  zcr_min_01  mfcc_min_04  \
# track_id
# 2                    0.438492    0.000000   -51.569004
# ...

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from scipy.stats import randint


y = df_flat["genre_top_grouped"].dropna()
X = df_flat[top_features].loc[y.index]#.drop(["genre_top_grouped"],axis=1).loc[y.index]
y_encoded = LabelEncoder().fit_transform(y)
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42, stratify=y)

# %%
import xgboost as xgb
# Create classification matrices
dtrain_clf = xgb.DMatrix(X_train, y_train, enable_categorical=True)
dtest_clf = xgb.DMatrix(X_test, y_test, enable_categorical=True)

# %%
params = {"objective": "multi:softprob", "tree_method": "hist", "num_class": 10, "max_depth": 8, "min_child_weight": 10}
n = 500

results = xgb.cv(
   params, dtrain_clf,
   num_boost_round=n,
   nfold=5,
   metrics=["mlogloss", "auc", "merror"],
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 4
#       1 params = {"objective": "multi:softprob", "tree_method": "hist", "num_class": 10, "max_depth": 8, "min_child_weight": 10}
#       2 n = 500
# ----> 4 results = xgb.cv(
#       5    params, dtrain_clf,
#       6    num_boost_round=n,
#       7    nfold=5,
#       8    metrics=["mlogloss", "auc", "merror"],
#       9 )
#
# AttributeError: 'XGBClassifier' object has no attribute 'cv'

# %%
results
# Out:
#      train-mlogloss-mean  train-mlogloss-std  train-auc-mean  train-auc-std  \
# 0               1.889602            0.003086        0.819748       0.001082
# 1               1.713675            0.003813        0.843308       0.000520
# 2               1.593591            0.004624        0.856080       0.001200
# 3               1.503327            0.004412        0.865628       0.001101
# 4               1.432593            0.004806        0.872737       0.001092
# ..                   ...                 ...             ...            ...
# 495             0.074570            0.001099        0.999994       0.000001
# 496             0.074250            0.001096        0.999994       0.000001
# 497             0.073954            0.001098        0.999995       0.000001
# 498             0.073613            0.001106        0.999995       0.000001
# 499             0.073307            0.001100        0.999995       0.000001
#
# ...

# %%
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold
from sklearn.metrics import f1_score, make_scorer

f1_weighted = make_scorer(f1_score, average="weighted")

param_dist = {
    "max_depth": [4, 6, 8, 10],
    "min_child_weight": [1, 5, 10],
    "subsample": [0.7, 0.8, 1.0],
    "colsample_bytree": [0.7, 0.8, 1.0],
}

cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

search = RandomizedSearchCV(
    xgb,
    param_distributions=param_dist,
    n_iter=20,
    scoring=f1_weighted,
    cv=cv,
    verbose=2,
    n_jobs=-1
)

search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [CV] END colsample_bytree=0.8, max_depth=4, min_child_weight=10, subsample=0.7; total time= 4.5min
# [CV] END colsample_bytree=0.8, max_depth=4, min_child_weight=10, subsample=0.7; total time= 4.6min
# [CV] END colsample_bytree=0.8, max_depth=4, min_child_weight=10, subsample=0.7; total time= 4.7min
# [CV] END colsample_bytree=1.0, max_depth=8, min_child_weight=10, subsample=0.7; total time=10.2min
# [CV] END colsample_bytree=1.0, max_depth=8, min_child_weight=10, subsample=0.7; total time=10.6min
# [CV] END colsample_bytree=1.0, max_depth=8, min_child_weight=10, subsample=0.7; total time=10.6min
# [CV] END colsample_bytree=1.0, max_depth=8, min_child_weight=5, subsample=1.0; total time=12.2min
# [CV] END colsample_bytree=1.0, max_depth=8, min_child_weight=5, subsample=1.0; total time=12.2min
# [CV] END colsample_bytree=0.7, max_depth=6, min_child_weight=5, subsample=1.0; total time= 7.8min
# ...

# %%
print("Best params:", search.best_params_)
print("Best CV F1:", search.best_score_)
# Out:
# Best params: {'subsample': 0.8, 'min_child_weight': 10, 'max_depth': 10, 'colsample_bytree': 0.8}
# Best CV F1: 0.6735860490211225

# %%
from sklearn.metrics import classification_report, confusion_matrix
best_xgb = search.best_estimator_
best_xgb.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 5
#       2 best_xgb = search.best_estimator_
#       3 best_xgb.fit(X_train,y_train)
# ----> 5 y_pred = best_.predict(X_test)
#       7 print(classification_report(y_test, y_pred))
#
# NameError: name 'best_' is not defined

# %%
y_pred = best_xgb.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.78      0.83       246
#            1       0.68      0.73      0.70      1874
#            2       0.64      0.76      0.69      2122
#            3       0.66      0.63      0.64       561
#            4       0.76      0.70      0.73       710
#            5       0.53      0.30      0.38       416
#            6       0.71      0.44      0.54       278
#            7       0.76      0.48      0.58       410
#            8       0.52      0.15      0.23       466
#            9       0.77      0.86      0.81      2837
#
#     accuracy                           0.70      9920
#    macro avg       0.69      0.58      0.61      9920
# weighted avg       0.69      0.70      0.69      9920

# %%
best_iter = results["test-mlogloss-mean"].idxmin()
best_score = results.loc[best_iter, "test-mlogloss-mean"]

# %%
best_iter
# Out:
# 224

# %%
importances = pd.Series(
    xgb.feature_importances_,
    index=X_train.columns
).sort_values(ascending=False)

# %%
importances[280:] #retirer chroma_stft_max
# Out:
# mfcc_skew_17          0.001906
# mfcc_kurtosis_07      0.001901
# mfcc_skew_18          0.001889
# mfcc_kurtosis_12      0.001886
# mfcc_skew_19          0.001848
# tonnetz_skew_03       0.001828
# tonnetz_skew_04       0.001766
# tonnetz_skew_05       0.001726
# chroma_stft_max_03    0.000000
# chroma_stft_max_02    0.000000
# chroma_stft_max_01    0.000000
# chroma_stft_max_04    0.000000
# chroma_stft_max_08    0.000000
# chroma_stft_max_05    0.000000
# chroma_stft_max_06    0.000000
# chroma_stft_max_07    0.000000
# chroma_stft_max_12    0.000000
# chroma_stft_max_09    0.000000
# chroma_stft_max_10    0.000000
# chroma_stft_max_11    0.000000
# dtype: float32

# %%
from sklearn.inspection import permutation_importance

r = permutation_importance(
    xgb,
    X_test,
    y_test,
    n_repeats=5,
    scoring="f1_weighted",
    random_state=42
)

perm_importance = pd.Series(
    r.importances_mean,
    index=X_test.columns
).sort_values()

# %%
top_features=perm_importance[150:].index.tolist()#garder les 30 premières pour voir, 0.64 accuracy, les 100 premières, 0.69, 150, 0.699, 0.68 avec es

# %%
from xgboost import XGBClassifier

xgb = XGBClassifier(
    max_depth=10,
    min_child_weight=10,
    eval_metric="mlogloss",
    learning_rate=0.1,
    n_estimators=500,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    early_stopping_rounds=50
)

xgb.fit(
    X_train,y_train, eval_set=[(X_test,y_test)],
    verbose=True
)
# Out:
# [0]	validation_0-mlogloss:2.08632
# [1]	validation_0-mlogloss:1.97573
# [2]	validation_0-mlogloss:1.88497
# [3]	validation_0-mlogloss:1.80795
# [4]	validation_0-mlogloss:1.74227
# [5]	validation_0-mlogloss:1.68428
# [6]	validation_0-mlogloss:1.63359
# [7]	validation_0-mlogloss:1.58781
# [8]	validation_0-mlogloss:1.54702
# [9]	validation_0-mlogloss:1.51065
# [10]	validation_0-mlogloss:1.47692
# [11]	validation_0-mlogloss:1.44614
# [12]	validation_0-mlogloss:1.41821
# [13]	validation_0-mlogloss:1.39255
# [14]	validation_0-mlogloss:1.36917
# [15]	validation_0-mlogloss:1.34676
# [16]	validation_0-mlogloss:1.32663
# [17]	validation_0-mlogloss:1.30791
# [18]	validation_0-mlogloss:1.29042
# [19]	validation_0-mlogloss:1.27450
# [20]	validation_0-mlogloss:1.26038
# [21]	validation_0-mlogloss:1.24659
# [22]	validation_0-mlogloss:1.23416
# [23]	validation_0-mlogloss:1.22249
# [24]	validation_0-mlogloss:1.21120
# [25]	validation_0-mlogloss:1.20030
# [26]	validation_0-mlogloss:1.19044
# ...

# %%
from sklearn.metrics import classification_report, confusion_matrix
y_pred = xgb.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.78      0.81       246
#            1       0.66      0.71      0.68      1874
#            2       0.62      0.75      0.68      2122
#            3       0.67      0.62      0.64       561
#            4       0.73      0.67      0.70       710
#            5       0.55      0.30      0.38       416
#            6       0.75      0.40      0.52       278
#            7       0.79      0.47      0.59       410
#            8       0.43      0.12      0.19       466
#            9       0.75      0.85      0.80      2837
#
#     accuracy                           0.69      9920
#    macro avg       0.68      0.56      0.60      9920
# weighted avg       0.68      0.69      0.67      9920

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.6873991935483871

# %%
p = y.value_counts(normalize=True)
entropy = -np.sum(p * np.log(p))
entropy
# Out:
# np.float64(1.9541560316347724)

# %%
Counter(y)
# Out:
# Counter({'Rock': 14182,
#          'Experimental': 10608,
#          'Electronic': 9372,
#          'Hip-Hop': 3552,
#          'Folk': 2803,
#          'Pop': 2332,
#          'Instrumental': 2079,
#          'Other': 2051,
#          'International': 1389,
#          'Classical': 1230})
