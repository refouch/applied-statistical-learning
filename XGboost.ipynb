# %% [markdown]
# # XGBoost
#
# Toujours avec des les features musicales agrégées Librosa, nous entraînons ici un modèle de classification *XGBoost*.
#
# ### I. Chargement, preprocessing des données et sélection des variables
#
# Comme pour la forêt aléatoire, nous reprenons le processus et les idées de sélection des variables développées dans *neural_net.ipynb*.

# %%
import numpy as np
import pandas as pd
from utils.load_data import fma_load


features = fma_load('data/fma_metadata/features.csv')
tracks = fma_load('data/fma_metadata/tracks.csv')

y = tracks['track','genre_top']

corr = features.corr()

threshold = 0.75

corr_matrix = corr.copy()

np.fill_diagonal(corr_matrix.values, 0) # Diagonal to zero

strong_corr = (corr_matrix.abs() > threshold)

pairs = []
for i in range(len(corr_matrix.columns)):
    for j in range(i+1, len(corr_matrix.columns)):
        if strong_corr.iloc[i, j]:
            pairs.append({
                "feature_1": corr_matrix.columns[i],
                "feature_2": corr_matrix.columns[j],
                "correlation": corr_matrix.iloc[i, j]
            })


features.drop(columns=['chroma_cqt','chroma_cens'],inplace=True)
features = features.loc[:, features.columns.get_level_values('statistics') != 'median']

features
# Out:
# feature    chroma_stft                                                    \
# statistics    kurtosis
# number              01        02        03        04        05        06
# track_id
# 2            -1.006041 -0.634076 -0.233752 -0.120917  0.004806  1.218982
# 3            -0.951502 -0.660734 -1.050015 -0.977441 -0.343043 -0.515404
# 5            -0.794551 -1.264806 -0.664387 -0.405196 -0.022688  0.014883
# 10            0.954931 -1.266404  0.030425 -0.646823  0.664217  0.082626
# 20           -0.048443 -0.543755 -1.336000 -0.410307 -0.684526 -0.960676
# ...                ...       ...       ...       ...       ...       ...
# 155316       -0.959207 -0.130793 -0.635587 -0.251981 -0.656534 -0.238574
# 155317       -0.965068 -0.679953 -1.051353 -0.852524 -0.872679 -0.740262
# 155318       -0.771414 -0.438261 -0.888968 -0.730804 -0.868208 -0.623147
# 155319       -0.984837 -0.198621 -0.923624 -0.825457 -1.035743 -0.919991
# 155320       -0.787214 -0.792066 -1.052318 -0.930889 -1.111142 -0.961365
#
# feature                                             ...   tonnetz            \
# statistics                                          ...       std
# number            07        08        09        10  ...        03        04
# track_id                                            ...
# 2           0.969103 -0.884986 -0.469190 -0.515475  ...  0.038974  0.054125
# 3          -0.973297 -1.261086 -1.132458 -0.953374  ...  0.051151  0.063831
# 5          -0.190766 -0.507027 -0.868905 -0.952605  ...  0.084997  0.040730
# 10         -1.241245  0.102074 -0.742071  0.670849  ...  0.088197  0.074358
# 20         -1.108473 -1.320151 -0.754329 -1.029887  ...  0.105521  0.095003
# ...              ...       ...       ...       ...  ...       ...       ...
# 155316     -0.372219 -0.661802 -0.297405 -0.533092  ...  0.102859  0.128410
# 155317     -0.737960 -1.060661 -1.029553 -0.949072  ...  0.135479  0.132964
# 155318     -0.855489 -0.950127 -0.725640 -0.694402  ...  0.089910  0.108324
# 155319     -0.655853 -0.887433 -0.398968 -0.233844  ...  0.092314  0.088311
# 155320     -0.890171 -0.987430 -0.638198 -1.095618  ...  0.099553  0.091421
#
# feature                               zcr                                \
# statistics                       kurtosis       max      mean       min
# number            05        06         01        01        01        01
# track_id
# 2           0.012226  0.012111   5.758890  0.459473  0.085629  0.000000
# 3           0.014212  0.017740   2.824694  0.466309  0.084578  0.000000
# 5           0.012691  0.014759   6.808415  0.375000  0.053114  0.000000
# 10          0.017952  0.013921  21.434212  0.452148  0.077515  0.000000
# 20          0.022492  0.021355  16.669037  0.469727  0.047225  0.000977
# ...              ...       ...        ...       ...       ...       ...
# 155316      0.022547  0.019816   4.448255  0.172852  0.028773  0.003906
# 155317      0.023548  0.026527   3.270612  0.196289  0.031116  0.002441
# 155318      0.017540  0.020471   2.356727  0.212891  0.038450  0.003418
# 155319      0.018328  0.017936   6.188604  0.167480  0.041480  0.004883
# 155320      0.020312  0.016794  21.756050  0.845215  0.075141  0.004395
#
# feature
# statistics      skew       std
# number            01        01
# track_id
# 2           2.089872  0.061448
# 3           1.716724  0.069330
# 5           2.193303  0.044861
# 10          3.542325  0.040800
# 20          3.189831  0.030993
# ...              ...       ...
# 155316      0.955388  0.012385
# 155317      1.283060  0.019059
# 155318      0.828569  0.017904
# 155319      1.818740  0.020133
# 155320      4.687204  0.137205
#
# [106574 rows x 300 columns]

# %%
df_flat = features.copy()
df_flat.columns = ['_'.join(col).strip() for col in df_flat.columns.values]

df_flat['genre_top'] = y

df_flat.dropna(inplace=True)

df_flat
# Out:
#           chroma_stft_kurtosis_01  chroma_stft_kurtosis_02  \
# track_id
# 2                       -1.006041                -0.634076
# 3                       -0.951502                -0.660734
# 5                       -0.794551                -1.264806
# 10                       0.954931                -1.266404
# 134                     -0.972450                -1.047674
# ...                           ...                      ...
# 155315                  -0.931622                -0.823569
# 155316                  -0.959207                -0.130793
# 155317                  -0.965068                -0.679953
# 155318                  -0.771414                -0.438261
# 155319                  -0.984837                -0.198621
#
#           chroma_stft_kurtosis_03  chroma_stft_kurtosis_04  \
# track_id
# 2                       -0.233752                -0.120917
# 3                       -1.050015                -0.977441
# 5                       -0.664387                -0.405196
# 10                       0.030425                -0.646823
# 134                     -1.312579                -1.120184
# ...                           ...                      ...
# 155315                  -1.235423                -1.213406
# 155316                  -0.635587                -0.251981
# 155317                  -1.051353                -0.852524
# 155318                  -0.888968                -0.730804
# 155319                  -0.923624                -0.825457
#
#           chroma_stft_kurtosis_05  chroma_stft_kurtosis_06  \
# track_id
# 2                        0.004806                 1.218982
# 3                       -0.343043                -0.515404
# 5                       -0.022688                 0.014883
# 10                       0.664217                 0.082626
# 134                     -1.280836                -1.215888
# ...                           ...                      ...
# 155315                  -0.999892                -0.672000
# 155316                  -0.656534                -0.238574
# 155317                  -0.872679                -0.740262
# 155318                  -0.868208                -0.623147
# 155319                  -1.035743                -0.919991
#
#           chroma_stft_kurtosis_07  chroma_stft_kurtosis_08  \
# track_id
# 2                        0.969103                -0.884986
# 3                       -0.973297                -1.261086
# 5                       -0.190766                -0.507027
# 10                      -1.241245                 0.102074
# 134                     -1.006120                -0.915774
# ...                           ...                      ...
# 155315                  -1.219753                -1.381937
# 155316                  -0.372219                -0.661802
# 155317                  -0.737960                -1.060661
# 155318                  -0.855489                -0.950127
# 155319                  -0.655853                -0.887433
#
#           chroma_stft_kurtosis_09  chroma_stft_kurtosis_10  ...  \
# track_id                                                    ...
# 2                       -0.469190                -0.515475  ...
# 3                       -1.132458                -0.953374  ...
# 5                       -0.868905                -0.952605  ...
# 10                      -0.742071                 0.670849  ...
# 134                     -0.781248                -1.012533  ...
# ...                           ...                      ...  ...
# 155315                  -1.270755                -1.129524  ...
# 155316                  -0.297405                -0.533092  ...
# 155317                  -1.029553                -0.949072  ...
# 155318                  -0.725640                -0.694402  ...
# 155319                  -0.398968                -0.233844  ...
#
#           tonnetz_std_04  tonnetz_std_05  tonnetz_std_06  zcr_kurtosis_01  \
# track_id
# 2               0.054125        0.012226        0.012111         5.758890
# 3               0.063831        0.014212        0.017740         2.824694
# 5               0.040730        0.012691        0.014759         6.808415
# 10              0.074358        0.017952        0.013921        21.434212
# 134             0.058766        0.016322        0.015819         4.731087
# ...                  ...             ...             ...              ...
# 155315          0.108577        0.016631        0.014705         6.947788
# 155316          0.128410        0.022547        0.019816         4.448255
# 155317          0.132964        0.023548        0.026527         3.270612
# 155318          0.108324        0.017540        0.020471         2.356727
# 155319          0.088311        0.018328        0.017936         6.188604
#
#           zcr_max_01  zcr_mean_01  zcr_min_01  zcr_skew_01  zcr_std_01  \
# track_id
# 2           0.459473     0.085629    0.000000     2.089872    0.061448
# 3           0.466309     0.084578    0.000000     1.716724    0.069330
# 5           0.375000     0.053114    0.000000     2.193303    0.044861
# 10          0.452148     0.077515    0.000000     3.542325    0.040800
# 134         0.419434     0.064370    0.000000     1.806106    0.054623
# ...              ...          ...         ...          ...         ...
# 155315      0.188477     0.037708    0.002930     1.764233    0.018679
# 155316      0.172852     0.028773    0.003906     0.955388    0.012385
# 155317      0.196289     0.031116    0.002441     1.283060    0.019059
# 155318      0.212891     0.038450    0.003418     0.828569    0.017904
# 155319      0.167480     0.041480    0.004883     1.818740    0.020133
#
#           genre_top
# track_id
# 2           Hip-Hop
# 3           Hip-Hop
# 5           Hip-Hop
# 10              Pop
# 134         Hip-Hop
# ...             ...
# 155315         Rock
# 155316         Rock
# 155317         Rock
# 155318         Rock
# 155319         Rock
#
# [49598 rows x 301 columns]

# %% [markdown]
# ## II. Création du XGBoost
#
# On retrace ici les choix d'entraînement de notre modèle *XGBoost*.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder


y = df_flat["genre_top"].dropna()

X = df_flat.drop(["genre_top"],axis=1).loc[y.index]

le = LabelEncoder()
y_encoded = le.fit_transform(y) #necessary for xgb
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)

# %% [markdown]
# Comme pour la forêt aléatoire, afin d'identifier rapidemment les meilleurs hyper-paramètres, on utilise `RandomizedSearchCV` mais cette fois-ci sur 3 *folds* pour gagner du temps de calcul (le modèle étant plus complexe qu'une forêt aléatoire).
#
# (De même, ce code prend longtemps à tourner, nous suggérons de sauter les deux cellules suviantes.)

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import f1_score, make_scorer

f1_weighted = make_scorer(f1_score, average="weighted")

param_dist = {
    "max_depth": [4, 6, 8, 10],
    "min_child_weight": [1, 5, 10],
    "subsample": [0.7, 0.8, 1.0],
    "colsample_bytree": [0.7, 0.8, 1.0],
}

cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

search = RandomizedSearchCV(
    xgb,
    param_distributions=param_dist,
    n_iter=20,
    scoring=f1_weighted,
    cv=cv,
    verbose=2,
    n_jobs=-1
)

search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [CV] END colsample_bytree=0.8, max_depth=4, min_child_weight=10, subsample=0.7; total time= 4.5min
# [CV] END colsample_bytree=0.8, max_depth=4, min_child_weight=10, subsample=0.7; total time= 4.6min
# [CV] END colsample_bytree=0.8, max_depth=4, min_child_weight=10, subsample=0.7; total time= 4.7min
# [CV] END colsample_bytree=1.0, max_depth=8, min_child_weight=10, subsample=0.7; total time=10.2min
# [CV] END colsample_bytree=1.0, max_depth=8, min_child_weight=10, subsample=0.7; total time=10.6min
# [CV] END colsample_bytree=1.0, max_depth=8, min_child_weight=10, subsample=0.7; total time=10.6min
# [CV] END colsample_bytree=1.0, max_depth=8, min_child_weight=5, subsample=1.0; total time=12.2min
# [CV] END colsample_bytree=1.0, max_depth=8, min_child_weight=5, subsample=1.0; total time=12.2min
# [CV] END colsample_bytree=0.7, max_depth=6, min_child_weight=5, subsample=1.0; total time= 7.8min
# [CV] END colsample_bytree=1.0, max_depth=8, min_child_weight=5, subsample=1.0; total time=12.6min
# [CV] END colsample_bytree=0.7, max_depth=6, min_child_weight=5, subsample=1.0; total time= 8.4min
# [CV] END colsample_bytree=0.7, max_depth=6, min_child_weight=5, subsample=1.0; total time= 8.6min
# [CV] END colsample_bytree=1.0, max_depth=10, min_child_weight=5, subsample=0.8; total time=13.9min
# [CV] END colsample_bytree=1.0, max_depth=10, min_child_weight=5, subsample=0.8; total time=14.2min
# [CV] END colsample_bytree=1.0, max_depth=10, min_child_weight=5, subsample=0.8; total time=14.2min
# [CV] END colsample_bytree=0.7, max_depth=10, min_child_weight=1, subsample=0.7; total time=17.2min
# [CV] END colsample_bytree=0.7, max_depth=10, min_child_weight=1, subsample=0.7; total time=17.4min
# [CV] END colsample_bytree=1.0, max_depth=4, min_child_weight=1, subsample=1.0; total time= 5.5min
# [CV] END colsample_bytree=0.7, max_depth=10, min_child_weight=1, subsample=0.7; total time=18.2min
# [CV] END colsample_bytree=1.0, max_depth=4, min_child_weight=1, subsample=1.0; total time= 5.4min
# [CV] END colsample_bytree=1.0, max_depth=4, min_child_weight=1, subsample=1.0; total time= 5.3min
# [CV] END colsample_bytree=1.0, max_depth=4, min_child_weight=10, subsample=0.8; total time= 4.7min
# [CV] END colsample_bytree=1.0, max_depth=4, min_child_weight=10, subsample=0.8; total time= 5.0min
# [CV] END colsample_bytree=1.0, max_depth=4, min_child_weight=10, subsample=0.8; total time= 5.4min
# [CV] END colsample_bytree=0.7, max_depth=10, min_child_weight=10, subsample=0.7; total time=10.2min
# [CV] END colsample_bytree=0.7, max_depth=10, min_child_weight=10, subsample=0.7; total time=10.5min
# [CV] END colsample_bytree=0.7, max_depth=10, min_child_weight=10, subsample=0.7; total time=10.9min
# [CV] END colsample_bytree=1.0, max_depth=4, min_child_weight=10, subsample=0.7; total time= 4.7min
# [CV] END colsample_bytree=1.0, max_depth=4, min_child_weight=10, subsample=0.7; total time= 4.9min
# [CV] END colsample_bytree=1.0, max_depth=4, min_child_weight=10, subsample=0.7; total time= 5.4min
# [CV] END colsample_bytree=1.0, max_depth=4, min_child_weight=5, subsample=0.7; total time= 5.0min
# [CV] END colsample_bytree=0.8, max_depth=8, min_child_weight=1, subsample=0.8; total time=14.6min
# [CV] END colsample_bytree=0.8, max_depth=8, min_child_weight=1, subsample=0.8; total time=14.9min
# [CV] END colsample_bytree=0.8, max_depth=8, min_child_weight=1, subsample=0.8; total time=15.4min
# [CV] END colsample_bytree=1.0, max_depth=4, min_child_weight=5, subsample=0.7; total time= 5.7min
# [CV] END colsample_bytree=1.0, max_depth=4, min_child_weight=5, subsample=0.7; total time= 5.3min
# [CV] END colsample_bytree=0.7, max_depth=6, min_child_weight=1, subsample=0.8; total time=10.2min
# [CV] END colsample_bytree=0.7, max_depth=6, min_child_weight=1, subsample=0.8; total time=10.4min
# [CV] END colsample_bytree=0.7, max_depth=10, min_child_weight=10, subsample=1.0; total time=11.4min
# [CV] END colsample_bytree=0.7, max_depth=10, min_child_weight=10, subsample=1.0; total time=11.1min
# [CV] END colsample_bytree=0.7, max_depth=6, min_child_weight=1, subsample=0.8; total time=10.6min
# [CV] END colsample_bytree=0.7, max_depth=10, min_child_weight=10, subsample=1.0; total time=11.6min
# [CV] END colsample_bytree=0.8, max_depth=10, min_child_weight=10, subsample=0.8; total time=10.7min
# [CV] END colsample_bytree=0.8, max_depth=10, min_child_weight=10, subsample=0.8; total time=12.0min
# [CV] END colsample_bytree=0.8, max_depth=10, min_child_weight=10, subsample=0.8; total time=11.6min
# [CV] END colsample_bytree=0.7, max_depth=4, min_child_weight=5, subsample=0.7; total time= 4.9min
# [CV] END colsample_bytree=0.7, max_depth=4, min_child_weight=5, subsample=0.7; total time= 4.7min
# [CV] END colsample_bytree=0.7, max_depth=4, min_child_weight=5, subsample=0.7; total time= 4.9min
# [CV] END colsample_bytree=0.8, max_depth=8, min_child_weight=5, subsample=0.7; total time=10.8min
# [CV] END colsample_bytree=0.8, max_depth=8, min_child_weight=5, subsample=0.7; total time=10.7min
# [CV] END colsample_bytree=1.0, max_depth=10, min_child_weight=5, subsample=1.0; total time=13.9min
# [CV] END colsample_bytree=0.8, max_depth=8, min_child_weight=5, subsample=0.7; total time=11.0min
# [CV] END colsample_bytree=1.0, max_depth=10, min_child_weight=5, subsample=1.0; total time=14.5min
# [CV] END colsample_bytree=1.0, max_depth=10, min_child_weight=5, subsample=1.0; total time=14.5min
# [CV] END colsample_bytree=0.8, max_depth=6, min_child_weight=1, subsample=0.8; total time=10.3min
# [CV] END colsample_bytree=0.8, max_depth=6, min_child_weight=1, subsample=0.8; total time= 9.5min
# [CV] END colsample_bytree=0.8, max_depth=6, min_child_weight=1, subsample=0.8; total time=10.0min
# [CV] END colsample_bytree=0.8, max_depth=10, min_child_weight=1, subsample=0.7; total time=17.3min
# [CV] END colsample_bytree=0.8, max_depth=10, min_child_weight=1, subsample=0.7; total time=17.6min
# [CV] END colsample_bytree=0.8, max_depth=10, min_child_weight=1, subsample=0.7; total time=16.8min
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=3, random_state=42, shuffle=True),
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=0.8, device=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric='mlogloss',
#                                            feature_types=None,
#                                            feature_weights=None, gamma=None...
#                                            min_child_weight=None, missing=nan,
#                                            monotone_constraints=None,
#                                            multi_strategy=None,
#                                            n_estimators=500, n_jobs=None,
#                                            num_parallel_tree=None, ...),
#                    n_iter=20, n_jobs=-1,
#                    param_distributions={'colsample_bytree': [0.7, 0.8, 1.0],
#                                         'max_depth': [4, 6, 8, 10],
#                                         'min_child_weight': [1, 5, 10],
#                                         'subsample': [0.7, 0.8, 1.0]},
#                    scoring=make_scorer(f1_score, response_method='predict', average=weighted),
#                    verbose=2)

# %%
print("Best params:", search.best_params_)
print("Best CV F1:", search.best_score_)
# Out:
# Best params: {'subsample': 0.8, 'min_child_weight': 10, 'max_depth': 10, 'colsample_bytree': 0.8}
# Best CV F1: 0.6735860490211225

# %%
from xgboost import XGBClassifier

xgb = XGBClassifier(
    max_depth=10,
    min_child_weight=10,
    n_estimators=500,
    colsample_bytree=0.8,
    learning_rate=0.1,
    eval_metric='mlogloss',
    use_label_encoder=False,
    random_state=42
)

xgb.fit(
    X_train, y_train,
    eval_set=[(X_test, y_test)],
    verbose=True
)
# Out:
# /opt/python/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [10:27:48] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [0]	validation_0-mlogloss:2.42850
# [1]	validation_0-mlogloss:2.26636
# [2]	validation_0-mlogloss:2.14001
# [3]	validation_0-mlogloss:2.03460
# [4]	validation_0-mlogloss:1.94586
# [5]	validation_0-mlogloss:1.86960
# [6]	validation_0-mlogloss:1.80307
# [7]	validation_0-mlogloss:1.74399
# [8]	validation_0-mlogloss:1.69187
# [9]	validation_0-mlogloss:1.64488
# [10]	validation_0-mlogloss:1.60203
# [11]	validation_0-mlogloss:1.56274
# [12]	validation_0-mlogloss:1.52698
# [13]	validation_0-mlogloss:1.49524
# [14]	validation_0-mlogloss:1.46535
# [15]	validation_0-mlogloss:1.43828
# [16]	validation_0-mlogloss:1.41251
# [17]	validation_0-mlogloss:1.38976
# [18]	validation_0-mlogloss:1.36814
# [19]	validation_0-mlogloss:1.34784
# [20]	validation_0-mlogloss:1.32869
# [21]	validation_0-mlogloss:1.31078
# [22]	validation_0-mlogloss:1.29480
# [23]	validation_0-mlogloss:1.27971
# [24]	validation_0-mlogloss:1.26593
# [25]	validation_0-mlogloss:1.25264
# [26]	validation_0-mlogloss:1.24058
# [27]	validation_0-mlogloss:1.22905
# [28]	validation_0-mlogloss:1.21787
# [29]	validation_0-mlogloss:1.20805
# [30]	validation_0-mlogloss:1.19816
# [31]	validation_0-mlogloss:1.18893
# [32]	validation_0-mlogloss:1.18012
# [33]	validation_0-mlogloss:1.17168
# [34]	validation_0-mlogloss:1.16378
# [35]	validation_0-mlogloss:1.15646
# [36]	validation_0-mlogloss:1.14929
# [37]	validation_0-mlogloss:1.14243
# [38]	validation_0-mlogloss:1.13630
# [39]	validation_0-mlogloss:1.13045
# [40]	validation_0-mlogloss:1.12478
# [41]	validation_0-mlogloss:1.11932
# [42]	validation_0-mlogloss:1.11387
# [43]	validation_0-mlogloss:1.10883
# [44]	validation_0-mlogloss:1.10411
# [45]	validation_0-mlogloss:1.09931
# [46]	validation_0-mlogloss:1.09479
# [47]	validation_0-mlogloss:1.09069
# [48]	validation_0-mlogloss:1.08656
# [49]	validation_0-mlogloss:1.08270
# [50]	validation_0-mlogloss:1.07927
# [51]	validation_0-mlogloss:1.07562
# [52]	validation_0-mlogloss:1.07223
# [53]	validation_0-mlogloss:1.06878
# [54]	validation_0-mlogloss:1.06568
# [55]	validation_0-mlogloss:1.06286
# [56]	validation_0-mlogloss:1.06009
# [57]	validation_0-mlogloss:1.05776
# [58]	validation_0-mlogloss:1.05526
# [59]	validation_0-mlogloss:1.05247
# [60]	validation_0-mlogloss:1.05004
# [61]	validation_0-mlogloss:1.04800
# [62]	validation_0-mlogloss:1.04550
# [63]	validation_0-mlogloss:1.04372
# [64]	validation_0-mlogloss:1.04142
# [65]	validation_0-mlogloss:1.03946
# [66]	validation_0-mlogloss:1.03738
# [67]	validation_0-mlogloss:1.03539
# [68]	validation_0-mlogloss:1.03379
# [69]	validation_0-mlogloss:1.03200
# [70]	validation_0-mlogloss:1.03070
# [71]	validation_0-mlogloss:1.02884
# [72]	validation_0-mlogloss:1.02722
# [73]	validation_0-mlogloss:1.02532
# [74]	validation_0-mlogloss:1.02385
# [75]	validation_0-mlogloss:1.02235
# [76]	validation_0-mlogloss:1.02097
# [77]	validation_0-mlogloss:1.01961
# [78]	validation_0-mlogloss:1.01817
# [79]	validation_0-mlogloss:1.01698
# [80]	validation_0-mlogloss:1.01572
# [81]	validation_0-mlogloss:1.01467
# [82]	validation_0-mlogloss:1.01361
# [83]	validation_0-mlogloss:1.01280
# [84]	validation_0-mlogloss:1.01200
# [85]	validation_0-mlogloss:1.01086
# [86]	validation_0-mlogloss:1.00968
# [87]	validation_0-mlogloss:1.00848
# [88]	validation_0-mlogloss:1.00734
# [89]	validation_0-mlogloss:1.00642
# [90]	validation_0-mlogloss:1.00540
# [91]	validation_0-mlogloss:1.00448
# [92]	validation_0-mlogloss:1.00338
# [93]	validation_0-mlogloss:1.00244
# [94]	validation_0-mlogloss:1.00140
# [95]	validation_0-mlogloss:1.00066
# [96]	validation_0-mlogloss:0.99986
# [97]	validation_0-mlogloss:0.99904
# [98]	validation_0-mlogloss:0.99846
# [99]	validation_0-mlogloss:0.99753
# [100]	validation_0-mlogloss:0.99677
# [101]	validation_0-mlogloss:0.99605
# [102]	validation_0-mlogloss:0.99519
# [103]	validation_0-mlogloss:0.99442
# [104]	validation_0-mlogloss:0.99365
# [105]	validation_0-mlogloss:0.99293
# [106]	validation_0-mlogloss:0.99237
# [107]	validation_0-mlogloss:0.99198
# [108]	validation_0-mlogloss:0.99138
# [109]	validation_0-mlogloss:0.99112
# [110]	validation_0-mlogloss:0.99071
# [111]	validation_0-mlogloss:0.99016
# [112]	validation_0-mlogloss:0.98958
# [113]	validation_0-mlogloss:0.98889
# [114]	validation_0-mlogloss:0.98842
# [115]	validation_0-mlogloss:0.98800
# [116]	validation_0-mlogloss:0.98726
# [117]	validation_0-mlogloss:0.98674
# [118]	validation_0-mlogloss:0.98621
# [119]	validation_0-mlogloss:0.98566
# [120]	validation_0-mlogloss:0.98505
# [121]	validation_0-mlogloss:0.98472
# [122]	validation_0-mlogloss:0.98431
# [123]	validation_0-mlogloss:0.98404
# [124]	validation_0-mlogloss:0.98352
# [125]	validation_0-mlogloss:0.98333
# [126]	validation_0-mlogloss:0.98293
# [127]	validation_0-mlogloss:0.98257
# [128]	validation_0-mlogloss:0.98210
# [129]	validation_0-mlogloss:0.98176
# [130]	validation_0-mlogloss:0.98143
# [131]	validation_0-mlogloss:0.98110
# [132]	validation_0-mlogloss:0.98087
# [133]	validation_0-mlogloss:0.98054
# [134]	validation_0-mlogloss:0.98027
# [135]	validation_0-mlogloss:0.98001
# [136]	validation_0-mlogloss:0.97949
# [137]	validation_0-mlogloss:0.97922
# [138]	validation_0-mlogloss:0.97898
# [139]	validation_0-mlogloss:0.97849
# [140]	validation_0-mlogloss:0.97821
# [141]	validation_0-mlogloss:0.97773
# [142]	validation_0-mlogloss:0.97752
# [143]	validation_0-mlogloss:0.97743
# [144]	validation_0-mlogloss:0.97724
# [145]	validation_0-mlogloss:0.97697
# [146]	validation_0-mlogloss:0.97671
# [147]	validation_0-mlogloss:0.97655
# [148]	validation_0-mlogloss:0.97655
# [149]	validation_0-mlogloss:0.97651
# [150]	validation_0-mlogloss:0.97633
# [151]	validation_0-mlogloss:0.97606
# [152]	validation_0-mlogloss:0.97598
# [153]	validation_0-mlogloss:0.97596
# [154]	validation_0-mlogloss:0.97568
# [155]	validation_0-mlogloss:0.97562
# [156]	validation_0-mlogloss:0.97563
# [157]	validation_0-mlogloss:0.97544
# [158]	validation_0-mlogloss:0.97530
# [159]	validation_0-mlogloss:0.97504
# [160]	validation_0-mlogloss:0.97482
# [161]	validation_0-mlogloss:0.97483
# [162]	validation_0-mlogloss:0.97457
# [163]	validation_0-mlogloss:0.97451
# [164]	validation_0-mlogloss:0.97446
# [165]	validation_0-mlogloss:0.97460
# [166]	validation_0-mlogloss:0.97433
# [167]	validation_0-mlogloss:0.97416
# [168]	validation_0-mlogloss:0.97395
# [169]	validation_0-mlogloss:0.97386
# [170]	validation_0-mlogloss:0.97366
# [171]	validation_0-mlogloss:0.97357
# [172]	validation_0-mlogloss:0.97368
# [173]	validation_0-mlogloss:0.97348
# [174]	validation_0-mlogloss:0.97343
# [175]	validation_0-mlogloss:0.97325
# [176]	validation_0-mlogloss:0.97314
# [177]	validation_0-mlogloss:0.97290
# [178]	validation_0-mlogloss:0.97272
# [179]	validation_0-mlogloss:0.97265
# [180]	validation_0-mlogloss:0.97265
# [181]	validation_0-mlogloss:0.97251
# [182]	validation_0-mlogloss:0.97243
# [183]	validation_0-mlogloss:0.97219
# [184]	validation_0-mlogloss:0.97212
# [185]	validation_0-mlogloss:0.97186
# [186]	validation_0-mlogloss:0.97183
# [187]	validation_0-mlogloss:0.97165
# [188]	validation_0-mlogloss:0.97154
# [189]	validation_0-mlogloss:0.97136
# [190]	validation_0-mlogloss:0.97137
# [191]	validation_0-mlogloss:0.97109
# [192]	validation_0-mlogloss:0.97091
# [193]	validation_0-mlogloss:0.97086
# [194]	validation_0-mlogloss:0.97085
# [195]	validation_0-mlogloss:0.97079
# [196]	validation_0-mlogloss:0.97080
# [197]	validation_0-mlogloss:0.97090
# [198]	validation_0-mlogloss:0.97099
# [199]	validation_0-mlogloss:0.97095
# [200]	validation_0-mlogloss:0.97095
# [201]	validation_0-mlogloss:0.97101
# [202]	validation_0-mlogloss:0.97081
# [203]	validation_0-mlogloss:0.97072
# [204]	validation_0-mlogloss:0.97062
# [205]	validation_0-mlogloss:0.97052
# [206]	validation_0-mlogloss:0.97039
# [207]	validation_0-mlogloss:0.97022
# [208]	validation_0-mlogloss:0.97011
# [209]	validation_0-mlogloss:0.97010
# [210]	validation_0-mlogloss:0.97028
# [211]	validation_0-mlogloss:0.97034
# [212]	validation_0-mlogloss:0.97030
# [213]	validation_0-mlogloss:0.97036
# [214]	validation_0-mlogloss:0.97025
# [215]	validation_0-mlogloss:0.97021
# [216]	validation_0-mlogloss:0.97035
# [217]	validation_0-mlogloss:0.97032
# [218]	validation_0-mlogloss:0.97026
# [219]	validation_0-mlogloss:0.97040
# [220]	validation_0-mlogloss:0.97033
# [221]	validation_0-mlogloss:0.97033
# [222]	validation_0-mlogloss:0.97030
# [223]	validation_0-mlogloss:0.97015
# [224]	validation_0-mlogloss:0.97017
# [225]	validation_0-mlogloss:0.97027
# [226]	validation_0-mlogloss:0.97040
# [227]	validation_0-mlogloss:0.97041
# [228]	validation_0-mlogloss:0.97055
# [229]	validation_0-mlogloss:0.97067
# [230]	validation_0-mlogloss:0.97068
# [231]	validation_0-mlogloss:0.97074
# [232]	validation_0-mlogloss:0.97067
# [233]	validation_0-mlogloss:0.97079
# [234]	validation_0-mlogloss:0.97064
# [235]	validation_0-mlogloss:0.97067
# [236]	validation_0-mlogloss:0.97055
# [237]	validation_0-mlogloss:0.97062
# [238]	validation_0-mlogloss:0.97057
# [239]	validation_0-mlogloss:0.97069
# [240]	validation_0-mlogloss:0.97050
# [241]	validation_0-mlogloss:0.97053
# [242]	validation_0-mlogloss:0.97063
# [243]	validation_0-mlogloss:0.97051
# [244]	validation_0-mlogloss:0.97070
# [245]	validation_0-mlogloss:0.97078
# [246]	validation_0-mlogloss:0.97085
# [247]	validation_0-mlogloss:0.97064
# [248]	validation_0-mlogloss:0.97070
# [249]	validation_0-mlogloss:0.97069
# [250]	validation_0-mlogloss:0.97072
# [251]	validation_0-mlogloss:0.97070
# [252]	validation_0-mlogloss:0.97074
# [253]	validation_0-mlogloss:0.97070
# [254]	validation_0-mlogloss:0.97071
# [255]	validation_0-mlogloss:0.97070
# [256]	validation_0-mlogloss:0.97076
# [257]	validation_0-mlogloss:0.97085
# [258]	validation_0-mlogloss:0.97101
# [259]	validation_0-mlogloss:0.97117
# [260]	validation_0-mlogloss:0.97133
# [261]	validation_0-mlogloss:0.97138
# [262]	validation_0-mlogloss:0.97132
# [263]	validation_0-mlogloss:0.97151
# [264]	validation_0-mlogloss:0.97152
# [265]	validation_0-mlogloss:0.97164
# [266]	validation_0-mlogloss:0.97179
# [267]	validation_0-mlogloss:0.97181
# [268]	validation_0-mlogloss:0.97182
# [269]	validation_0-mlogloss:0.97188
# [270]	validation_0-mlogloss:0.97205
# [271]	validation_0-mlogloss:0.97213
# [272]	validation_0-mlogloss:0.97214
# [273]	validation_0-mlogloss:0.97227
# [274]	validation_0-mlogloss:0.97247
# [275]	validation_0-mlogloss:0.97259
# [276]	validation_0-mlogloss:0.97255
# [277]	validation_0-mlogloss:0.97262
# [278]	validation_0-mlogloss:0.97273
# [279]	validation_0-mlogloss:0.97274
# [280]	validation_0-mlogloss:0.97277
# [281]	validation_0-mlogloss:0.97280
# [282]	validation_0-mlogloss:0.97278
# [283]	validation_0-mlogloss:0.97291
# [284]	validation_0-mlogloss:0.97308
# [285]	validation_0-mlogloss:0.97319
# [286]	validation_0-mlogloss:0.97332
# [287]	validation_0-mlogloss:0.97329
# [288]	validation_0-mlogloss:0.97351
# [289]	validation_0-mlogloss:0.97356
# [290]	validation_0-mlogloss:0.97365
# [291]	validation_0-mlogloss:0.97372
# [292]	validation_0-mlogloss:0.97385
# [293]	validation_0-mlogloss:0.97395
# [294]	validation_0-mlogloss:0.97415
# [295]	validation_0-mlogloss:0.97410
# [296]	validation_0-mlogloss:0.97427
# [297]	validation_0-mlogloss:0.97444
# [298]	validation_0-mlogloss:0.97457
# [299]	validation_0-mlogloss:0.97462
# [300]	validation_0-mlogloss:0.97464
# [301]	validation_0-mlogloss:0.97475
# [302]	validation_0-mlogloss:0.97496
# [303]	validation_0-mlogloss:0.97498
# [304]	validation_0-mlogloss:0.97512
# [305]	validation_0-mlogloss:0.97532
# [306]	validation_0-mlogloss:0.97526
# [307]	validation_0-mlogloss:0.97521
# [308]	validation_0-mlogloss:0.97527
# [309]	validation_0-mlogloss:0.97528
# [310]	validation_0-mlogloss:0.97530
# [311]	validation_0-mlogloss:0.97530
# [312]	validation_0-mlogloss:0.97532
# [313]	validation_0-mlogloss:0.97530
# [314]	validation_0-mlogloss:0.97543
# [315]	validation_0-mlogloss:0.97561
# [316]	validation_0-mlogloss:0.97560
# [317]	validation_0-mlogloss:0.97567
# [318]	validation_0-mlogloss:0.97566
# [319]	validation_0-mlogloss:0.97569
# [320]	validation_0-mlogloss:0.97574
# [321]	validation_0-mlogloss:0.97572
# [322]	validation_0-mlogloss:0.97593
# [323]	validation_0-mlogloss:0.97612
# [324]	validation_0-mlogloss:0.97617
# [325]	validation_0-mlogloss:0.97615
# [326]	validation_0-mlogloss:0.97623
# [327]	validation_0-mlogloss:0.97623
# [328]	validation_0-mlogloss:0.97635
# [329]	validation_0-mlogloss:0.97638
# [330]	validation_0-mlogloss:0.97637
# [331]	validation_0-mlogloss:0.97632
# [332]	validation_0-mlogloss:0.97645
# [333]	validation_0-mlogloss:0.97646
# [334]	validation_0-mlogloss:0.97658
# [335]	validation_0-mlogloss:0.97669
# [336]	validation_0-mlogloss:0.97683
# [337]	validation_0-mlogloss:0.97696
# [338]	validation_0-mlogloss:0.97711
# [339]	validation_0-mlogloss:0.97714
# [340]	validation_0-mlogloss:0.97723
# [341]	validation_0-mlogloss:0.97733
# [342]	validation_0-mlogloss:0.97735
# [343]	validation_0-mlogloss:0.97745
# [344]	validation_0-mlogloss:0.97758
# [345]	validation_0-mlogloss:0.97766
# [346]	validation_0-mlogloss:0.97784
# [347]	validation_0-mlogloss:0.97792
# [348]	validation_0-mlogloss:0.97789
# [349]	validation_0-mlogloss:0.97795
# [350]	validation_0-mlogloss:0.97803
# [351]	validation_0-mlogloss:0.97813
# [352]	validation_0-mlogloss:0.97813
# [353]	validation_0-mlogloss:0.97821
# [354]	validation_0-mlogloss:0.97839
# [355]	validation_0-mlogloss:0.97847
# [356]	validation_0-mlogloss:0.97847
# [357]	validation_0-mlogloss:0.97870
# [358]	validation_0-mlogloss:0.97870
# [359]	validation_0-mlogloss:0.97875
# [360]	validation_0-mlogloss:0.97883
# [361]	validation_0-mlogloss:0.97885
# [362]	validation_0-mlogloss:0.97901
# [363]	validation_0-mlogloss:0.97906
# [364]	validation_0-mlogloss:0.97908
# [365]	validation_0-mlogloss:0.97907
# [366]	validation_0-mlogloss:0.97906
# [367]	validation_0-mlogloss:0.97910
# [368]	validation_0-mlogloss:0.97916
# [369]	validation_0-mlogloss:0.97920
# [370]	validation_0-mlogloss:0.97930
# [371]	validation_0-mlogloss:0.97927
# [372]	validation_0-mlogloss:0.97929
# [373]	validation_0-mlogloss:0.97937
# [374]	validation_0-mlogloss:0.97945
# [375]	validation_0-mlogloss:0.97936
# [376]	validation_0-mlogloss:0.97942
# [377]	validation_0-mlogloss:0.97951
# [378]	validation_0-mlogloss:0.97963
# [379]	validation_0-mlogloss:0.97964
# [380]	validation_0-mlogloss:0.97966
# [381]	validation_0-mlogloss:0.97968
# [382]	validation_0-mlogloss:0.97978
# [383]	validation_0-mlogloss:0.97982
# [384]	validation_0-mlogloss:0.97994
# [385]	validation_0-mlogloss:0.98003
# [386]	validation_0-mlogloss:0.98019
# [387]	validation_0-mlogloss:0.98014
# [388]	validation_0-mlogloss:0.98028
# [389]	validation_0-mlogloss:0.98034
# [390]	validation_0-mlogloss:0.98044
# [391]	validation_0-mlogloss:0.98043
# [392]	validation_0-mlogloss:0.98045
# [393]	validation_0-mlogloss:0.98050
# [394]	validation_0-mlogloss:0.98075
# [395]	validation_0-mlogloss:0.98079
# [396]	validation_0-mlogloss:0.98083
# [397]	validation_0-mlogloss:0.98080
# [398]	validation_0-mlogloss:0.98094
# [399]	validation_0-mlogloss:0.98108
# [400]	validation_0-mlogloss:0.98109
# [401]	validation_0-mlogloss:0.98122
# [402]	validation_0-mlogloss:0.98117
# [403]	validation_0-mlogloss:0.98129
# [404]	validation_0-mlogloss:0.98147
# [405]	validation_0-mlogloss:0.98146
# [406]	validation_0-mlogloss:0.98164
# [407]	validation_0-mlogloss:0.98175
# [408]	validation_0-mlogloss:0.98182
# [409]	validation_0-mlogloss:0.98185
# [410]	validation_0-mlogloss:0.98191
# [411]	validation_0-mlogloss:0.98197
# [412]	validation_0-mlogloss:0.98206
# [413]	validation_0-mlogloss:0.98210
# [414]	validation_0-mlogloss:0.98212
# [415]	validation_0-mlogloss:0.98223
# [416]	validation_0-mlogloss:0.98222
# [417]	validation_0-mlogloss:0.98234
# [418]	validation_0-mlogloss:0.98242
# [419]	validation_0-mlogloss:0.98249
# [420]	validation_0-mlogloss:0.98252
# [421]	validation_0-mlogloss:0.98259
# [422]	validation_0-mlogloss:0.98271
# [423]	validation_0-mlogloss:0.98268
# [424]	validation_0-mlogloss:0.98278
# [425]	validation_0-mlogloss:0.98280
# [426]	validation_0-mlogloss:0.98287
# [427]	validation_0-mlogloss:0.98305
# [428]	validation_0-mlogloss:0.98314
# [429]	validation_0-mlogloss:0.98329
# [430]	validation_0-mlogloss:0.98328
# [431]	validation_0-mlogloss:0.98333
# [432]	validation_0-mlogloss:0.98339
# [433]	validation_0-mlogloss:0.98352
# [434]	validation_0-mlogloss:0.98352
# [435]	validation_0-mlogloss:0.98351
# [436]	validation_0-mlogloss:0.98358
# [437]	validation_0-mlogloss:0.98367
# [438]	validation_0-mlogloss:0.98386
# [439]	validation_0-mlogloss:0.98394
# [440]	validation_0-mlogloss:0.98403
# [441]	validation_0-mlogloss:0.98406
# [442]	validation_0-mlogloss:0.98423
# [443]	validation_0-mlogloss:0.98431
# [444]	validation_0-mlogloss:0.98452
# [445]	validation_0-mlogloss:0.98468
# [446]	validation_0-mlogloss:0.98470
# [447]	validation_0-mlogloss:0.98471
# [448]	validation_0-mlogloss:0.98484
# [449]	validation_0-mlogloss:0.98500
# [450]	validation_0-mlogloss:0.98513
# [451]	validation_0-mlogloss:0.98511
# [452]	validation_0-mlogloss:0.98505
# [453]	validation_0-mlogloss:0.98517
# [454]	validation_0-mlogloss:0.98514
# [455]	validation_0-mlogloss:0.98519
# [456]	validation_0-mlogloss:0.98526
# [457]	validation_0-mlogloss:0.98536
# [458]	validation_0-mlogloss:0.98537
# [459]	validation_0-mlogloss:0.98564
# [460]	validation_0-mlogloss:0.98564
# [461]	validation_0-mlogloss:0.98570
# [462]	validation_0-mlogloss:0.98576
# [463]	validation_0-mlogloss:0.98579
# [464]	validation_0-mlogloss:0.98587
# [465]	validation_0-mlogloss:0.98602
# [466]	validation_0-mlogloss:0.98622
# [467]	validation_0-mlogloss:0.98635
# [468]	validation_0-mlogloss:0.98651
# [469]	validation_0-mlogloss:0.98664
# [470]	validation_0-mlogloss:0.98679
# [471]	validation_0-mlogloss:0.98684
# [472]	validation_0-mlogloss:0.98686
# [473]	validation_0-mlogloss:0.98689
# [474]	validation_0-mlogloss:0.98694
# [475]	validation_0-mlogloss:0.98704
# [476]	validation_0-mlogloss:0.98715
# [477]	validation_0-mlogloss:0.98725
# [478]	validation_0-mlogloss:0.98731
# [479]	validation_0-mlogloss:0.98736
# [480]	validation_0-mlogloss:0.98743
# [481]	validation_0-mlogloss:0.98745
# [482]	validation_0-mlogloss:0.98759
# [483]	validation_0-mlogloss:0.98763
# [484]	validation_0-mlogloss:0.98773
# [485]	validation_0-mlogloss:0.98778
# [486]	validation_0-mlogloss:0.98799
# [487]	validation_0-mlogloss:0.98815
# [488]	validation_0-mlogloss:0.98823
# [489]	validation_0-mlogloss:0.98830
# [490]	validation_0-mlogloss:0.98841
# [491]	validation_0-mlogloss:0.98848
# [492]	validation_0-mlogloss:0.98863
# [493]	validation_0-mlogloss:0.98871
# [494]	validation_0-mlogloss:0.98875
# [495]	validation_0-mlogloss:0.98884
# [496]	validation_0-mlogloss:0.98889
# [497]	validation_0-mlogloss:0.98908
# [498]	validation_0-mlogloss:0.98919
# [499]	validation_0-mlogloss:0.98927
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=10, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=500, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

y_pred = xgb.predict(X_test)

# to have classes labels instead of numbers
y_pred_labels = le.inverse_transform(y_pred)
y_test_labels = le.inverse_transform(y_test)

print(classification_report(y_test_labels, y_pred_labels))
accuracy = accuracy_score(y_test_labels, y_pred_labels)
print("Accuracy:", accuracy)
# Out:
#                      precision    recall  f1-score   support
#
#               Blues       1.00      0.09      0.17        22
#           Classical       0.85      0.83      0.84       246
#             Country       0.70      0.18      0.29        39
#          Electronic       0.67      0.74      0.70      1874
#        Experimental       0.64      0.75      0.69      2122
#                Folk       0.69      0.64      0.66       561
#             Hip-Hop       0.74      0.66      0.70       710
#        Instrumental       0.52      0.28      0.36       416
#       International       0.84      0.46      0.60       278
#                Jazz       0.71      0.21      0.32       114
# Old-Time / Historic       0.94      0.95      0.94       111
#               Other       0.00      0.00      0.00         5
#                 Pop       0.53      0.18      0.27       466
#                Rock       0.76      0.85      0.80      2836
#            Soul-RnB       0.75      0.09      0.15        35
#              Spoken       0.62      0.46      0.53        85
#
#            accuracy                           0.70      9920
#           macro avg       0.68      0.46      0.50      9920
#        weighted avg       0.69      0.70      0.68      9920
#
# Accuracy: 0.7
# /opt/python/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/python/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/python/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# On constate que très vite la fonction de perte atteint un plancher autour de 0.98. Nous essayons donc d'utiliser de l'*early-stopping*. Même si les résultats sont légèrement moins bons, on diminue presque par deux la durée de l'entraînement ce qui constitue un gain de temps non négligeable.

# %%
xgb = XGBClassifier(
    max_depth=10,
    min_child_weight=10,
    eval_metric="mlogloss",
    learning_rate=0.1,
    n_estimators=1000,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    early_stopping_rounds=50
)

xgb.fit(
    X_train,y_train, eval_set=[(X_test,y_test)],
    verbose=True
)
# Out:
# [0]	validation_0-mlogloss:2.43159
# [1]	validation_0-mlogloss:2.27037
# [2]	validation_0-mlogloss:2.14419
# [3]	validation_0-mlogloss:2.03920
# [4]	validation_0-mlogloss:1.95128
# [5]	validation_0-mlogloss:1.87595
# [6]	validation_0-mlogloss:1.80929
# [7]	validation_0-mlogloss:1.75008
# [8]	validation_0-mlogloss:1.69804
# [9]	validation_0-mlogloss:1.65006
# [10]	validation_0-mlogloss:1.60699
# [11]	validation_0-mlogloss:1.56769
# [12]	validation_0-mlogloss:1.53280
# [13]	validation_0-mlogloss:1.49997
# [14]	validation_0-mlogloss:1.46983
# [15]	validation_0-mlogloss:1.44285
# [16]	validation_0-mlogloss:1.41700
# [17]	validation_0-mlogloss:1.39293
# [18]	validation_0-mlogloss:1.37076
# [19]	validation_0-mlogloss:1.35077
# [20]	validation_0-mlogloss:1.33265
# [21]	validation_0-mlogloss:1.31524
# [22]	validation_0-mlogloss:1.29892
# [23]	validation_0-mlogloss:1.28383
# [24]	validation_0-mlogloss:1.26977
# [25]	validation_0-mlogloss:1.25606
# [26]	validation_0-mlogloss:1.24425
# [27]	validation_0-mlogloss:1.23240
# [28]	validation_0-mlogloss:1.22139
# [29]	validation_0-mlogloss:1.21096
# [30]	validation_0-mlogloss:1.20124
# [31]	validation_0-mlogloss:1.19241
# [32]	validation_0-mlogloss:1.18334
# [33]	validation_0-mlogloss:1.17514
# [34]	validation_0-mlogloss:1.16749
# [35]	validation_0-mlogloss:1.16002
# [36]	validation_0-mlogloss:1.15338
# [37]	validation_0-mlogloss:1.14627
# [38]	validation_0-mlogloss:1.13920
# [39]	validation_0-mlogloss:1.13320
# [40]	validation_0-mlogloss:1.12732
# [41]	validation_0-mlogloss:1.12193
# [42]	validation_0-mlogloss:1.11686
# [43]	validation_0-mlogloss:1.11197
# [44]	validation_0-mlogloss:1.10753
# [45]	validation_0-mlogloss:1.10267
# [46]	validation_0-mlogloss:1.09847
# [47]	validation_0-mlogloss:1.09401
# [48]	validation_0-mlogloss:1.09045
# [49]	validation_0-mlogloss:1.08690
# [50]	validation_0-mlogloss:1.08315
# [51]	validation_0-mlogloss:1.07928
# [52]	validation_0-mlogloss:1.07533
# [53]	validation_0-mlogloss:1.07211
# [54]	validation_0-mlogloss:1.06907
# [55]	validation_0-mlogloss:1.06633
# [56]	validation_0-mlogloss:1.06314
# [57]	validation_0-mlogloss:1.06091
# [58]	validation_0-mlogloss:1.05813
# [59]	validation_0-mlogloss:1.05558
# [60]	validation_0-mlogloss:1.05283
# [61]	validation_0-mlogloss:1.05073
# [62]	validation_0-mlogloss:1.04834
# [63]	validation_0-mlogloss:1.04599
# [64]	validation_0-mlogloss:1.04360
# [65]	validation_0-mlogloss:1.04133
# [66]	validation_0-mlogloss:1.03915
# [67]	validation_0-mlogloss:1.03740
# [68]	validation_0-mlogloss:1.03574
# [69]	validation_0-mlogloss:1.03380
# [70]	validation_0-mlogloss:1.03215
# [71]	validation_0-mlogloss:1.03080
# [72]	validation_0-mlogloss:1.02907
# [73]	validation_0-mlogloss:1.02741
# [74]	validation_0-mlogloss:1.02612
# [75]	validation_0-mlogloss:1.02440
# [76]	validation_0-mlogloss:1.02286
# [77]	validation_0-mlogloss:1.02148
# [78]	validation_0-mlogloss:1.02010
# [79]	validation_0-mlogloss:1.01888
# [80]	validation_0-mlogloss:1.01758
# [81]	validation_0-mlogloss:1.01641
# [82]	validation_0-mlogloss:1.01500
# [83]	validation_0-mlogloss:1.01393
# [84]	validation_0-mlogloss:1.01295
# [85]	validation_0-mlogloss:1.01219
# [86]	validation_0-mlogloss:1.01152
# [87]	validation_0-mlogloss:1.01015
# [88]	validation_0-mlogloss:1.00901
# [89]	validation_0-mlogloss:1.00752
# [90]	validation_0-mlogloss:1.00659
# [91]	validation_0-mlogloss:1.00526
# [92]	validation_0-mlogloss:1.00408
# [93]	validation_0-mlogloss:1.00304
# [94]	validation_0-mlogloss:1.00226
# [95]	validation_0-mlogloss:1.00114
# [96]	validation_0-mlogloss:1.00021
# [97]	validation_0-mlogloss:0.99951
# [98]	validation_0-mlogloss:0.99877
# [99]	validation_0-mlogloss:0.99810
# [100]	validation_0-mlogloss:0.99721
# [101]	validation_0-mlogloss:0.99630
# [102]	validation_0-mlogloss:0.99588
# [103]	validation_0-mlogloss:0.99501
# [104]	validation_0-mlogloss:0.99396
# [105]	validation_0-mlogloss:0.99306
# [106]	validation_0-mlogloss:0.99204
# [107]	validation_0-mlogloss:0.99141
# [108]	validation_0-mlogloss:0.99066
# [109]	validation_0-mlogloss:0.98997
# [110]	validation_0-mlogloss:0.98921
# [111]	validation_0-mlogloss:0.98873
# [112]	validation_0-mlogloss:0.98809
# [113]	validation_0-mlogloss:0.98774
# [114]	validation_0-mlogloss:0.98707
# [115]	validation_0-mlogloss:0.98646
# [116]	validation_0-mlogloss:0.98593
# [117]	validation_0-mlogloss:0.98549
# [118]	validation_0-mlogloss:0.98496
# [119]	validation_0-mlogloss:0.98448
# [120]	validation_0-mlogloss:0.98398
# [121]	validation_0-mlogloss:0.98350
# [122]	validation_0-mlogloss:0.98291
# [123]	validation_0-mlogloss:0.98238
# [124]	validation_0-mlogloss:0.98191
# [125]	validation_0-mlogloss:0.98145
# [126]	validation_0-mlogloss:0.98105
# [127]	validation_0-mlogloss:0.98072
# [128]	validation_0-mlogloss:0.98030
# [129]	validation_0-mlogloss:0.97971
# [130]	validation_0-mlogloss:0.97943
# [131]	validation_0-mlogloss:0.97925
# [132]	validation_0-mlogloss:0.97914
# [133]	validation_0-mlogloss:0.97886
# [134]	validation_0-mlogloss:0.97835
# [135]	validation_0-mlogloss:0.97815
# [136]	validation_0-mlogloss:0.97775
# [137]	validation_0-mlogloss:0.97715
# [138]	validation_0-mlogloss:0.97693
# [139]	validation_0-mlogloss:0.97668
# [140]	validation_0-mlogloss:0.97667
# [141]	validation_0-mlogloss:0.97633
# [142]	validation_0-mlogloss:0.97589
# [143]	validation_0-mlogloss:0.97551
# [144]	validation_0-mlogloss:0.97535
# [145]	validation_0-mlogloss:0.97499
# [146]	validation_0-mlogloss:0.97468
# [147]	validation_0-mlogloss:0.97424
# [148]	validation_0-mlogloss:0.97411
# [149]	validation_0-mlogloss:0.97389
# [150]	validation_0-mlogloss:0.97360
# [151]	validation_0-mlogloss:0.97305
# [152]	validation_0-mlogloss:0.97276
# [153]	validation_0-mlogloss:0.97250
# [154]	validation_0-mlogloss:0.97245
# [155]	validation_0-mlogloss:0.97234
# [156]	validation_0-mlogloss:0.97232
# [157]	validation_0-mlogloss:0.97215
# [158]	validation_0-mlogloss:0.97188
# [159]	validation_0-mlogloss:0.97170
# [160]	validation_0-mlogloss:0.97153
# [161]	validation_0-mlogloss:0.97133
# [162]	validation_0-mlogloss:0.97131
# [163]	validation_0-mlogloss:0.97099
# [164]	validation_0-mlogloss:0.97087
# [165]	validation_0-mlogloss:0.97051
# [166]	validation_0-mlogloss:0.97029
# [167]	validation_0-mlogloss:0.96999
# [168]	validation_0-mlogloss:0.96974
# [169]	validation_0-mlogloss:0.96965
# [170]	validation_0-mlogloss:0.96955
# [171]	validation_0-mlogloss:0.96932
# [172]	validation_0-mlogloss:0.96919
# [173]	validation_0-mlogloss:0.96917
# [174]	validation_0-mlogloss:0.96894
# [175]	validation_0-mlogloss:0.96880
# [176]	validation_0-mlogloss:0.96872
# [177]	validation_0-mlogloss:0.96858
# [178]	validation_0-mlogloss:0.96835
# [179]	validation_0-mlogloss:0.96820
# [180]	validation_0-mlogloss:0.96796
# [181]	validation_0-mlogloss:0.96781
# [182]	validation_0-mlogloss:0.96787
# [183]	validation_0-mlogloss:0.96747
# [184]	validation_0-mlogloss:0.96739
# [185]	validation_0-mlogloss:0.96743
# [186]	validation_0-mlogloss:0.96748
# [187]	validation_0-mlogloss:0.96741
# [188]	validation_0-mlogloss:0.96744
# [189]	validation_0-mlogloss:0.96745
# [190]	validation_0-mlogloss:0.96726
# [191]	validation_0-mlogloss:0.96712
# [192]	validation_0-mlogloss:0.96692
# [193]	validation_0-mlogloss:0.96695
# [194]	validation_0-mlogloss:0.96689
# [195]	validation_0-mlogloss:0.96662
# [196]	validation_0-mlogloss:0.96657
# [197]	validation_0-mlogloss:0.96667
# [198]	validation_0-mlogloss:0.96666
# [199]	validation_0-mlogloss:0.96653
# [200]	validation_0-mlogloss:0.96657
# [201]	validation_0-mlogloss:0.96650
# [202]	validation_0-mlogloss:0.96634
# [203]	validation_0-mlogloss:0.96624
# [204]	validation_0-mlogloss:0.96605
# [205]	validation_0-mlogloss:0.96602
# [206]	validation_0-mlogloss:0.96606
# [207]	validation_0-mlogloss:0.96607
# [208]	validation_0-mlogloss:0.96590
# [209]	validation_0-mlogloss:0.96579
# [210]	validation_0-mlogloss:0.96547
# [211]	validation_0-mlogloss:0.96539
# [212]	validation_0-mlogloss:0.96526
# [213]	validation_0-mlogloss:0.96524
# [214]	validation_0-mlogloss:0.96537
# [215]	validation_0-mlogloss:0.96536
# [216]	validation_0-mlogloss:0.96556
# [217]	validation_0-mlogloss:0.96576
# [218]	validation_0-mlogloss:0.96570
# [219]	validation_0-mlogloss:0.96564
# [220]	validation_0-mlogloss:0.96558
# [221]	validation_0-mlogloss:0.96552
# [222]	validation_0-mlogloss:0.96568
# [223]	validation_0-mlogloss:0.96558
# [224]	validation_0-mlogloss:0.96575
# [225]	validation_0-mlogloss:0.96582
# [226]	validation_0-mlogloss:0.96574
# [227]	validation_0-mlogloss:0.96584
# [228]	validation_0-mlogloss:0.96610
# [229]	validation_0-mlogloss:0.96623
# [230]	validation_0-mlogloss:0.96614
# [231]	validation_0-mlogloss:0.96609
# [232]	validation_0-mlogloss:0.96609
# [233]	validation_0-mlogloss:0.96590
# [234]	validation_0-mlogloss:0.96615
# [235]	validation_0-mlogloss:0.96620
# [236]	validation_0-mlogloss:0.96610
# [237]	validation_0-mlogloss:0.96592
# [238]	validation_0-mlogloss:0.96611
# [239]	validation_0-mlogloss:0.96614
# [240]	validation_0-mlogloss:0.96603
# [241]	validation_0-mlogloss:0.96610
# [242]	validation_0-mlogloss:0.96593
# [243]	validation_0-mlogloss:0.96609
# [244]	validation_0-mlogloss:0.96603
# [245]	validation_0-mlogloss:0.96617
# [246]	validation_0-mlogloss:0.96630
# [247]	validation_0-mlogloss:0.96647
# [248]	validation_0-mlogloss:0.96625
# [249]	validation_0-mlogloss:0.96614
# [250]	validation_0-mlogloss:0.96625
# [251]	validation_0-mlogloss:0.96646
# [252]	validation_0-mlogloss:0.96650
# [253]	validation_0-mlogloss:0.96637
# [254]	validation_0-mlogloss:0.96631
# [255]	validation_0-mlogloss:0.96625
# [256]	validation_0-mlogloss:0.96634
# [257]	validation_0-mlogloss:0.96649
# [258]	validation_0-mlogloss:0.96635
# [259]	validation_0-mlogloss:0.96618
# [260]	validation_0-mlogloss:0.96632
# [261]	validation_0-mlogloss:0.96621
# [262]	validation_0-mlogloss:0.96645
# [263]	validation_0-mlogloss:0.96635
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=50,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=10, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=1000, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
y_pred = xgb.predict(X_test)

y_pred_labels = le.inverse_transform(y_pred)
y_test_labels = le.inverse_transform(y_test)

print(classification_report(y_test_labels, y_pred_labels))
accuracy = accuracy_score(y_test_labels, y_pred_labels)
print("Accuracy:", accuracy)
# Out:
#                      precision    recall  f1-score   support
#
#               Blues       0.50      0.05      0.08        22
#           Classical       0.86      0.81      0.83       246
#             Country       0.83      0.13      0.22        39
#          Electronic       0.66      0.73      0.70      1874
#        Experimental       0.63      0.75      0.68      2122
#                Folk       0.65      0.63      0.64       561
#             Hip-Hop       0.73      0.65      0.69       710
#        Instrumental       0.52      0.28      0.37       416
#       International       0.84      0.44      0.58       278
#                Jazz       0.80      0.18      0.29       114
# Old-Time / Historic       0.92      0.92      0.92       111
#               Other       0.00      0.00      0.00         5
#                 Pop       0.50      0.14      0.22       466
#                Rock       0.75      0.84      0.79      2836
#            Soul-RnB       0.75      0.09      0.15        35
#              Spoken       0.62      0.45      0.52        85
#
#            accuracy                           0.69      9920
#           macro avg       0.66      0.44      0.48      9920
#        weighted avg       0.69      0.69      0.67      9920
#
# Accuracy: 0.6903225806451613
# /opt/python/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/python/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/python/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# ## III. Optimisation des performances
#
# Comme pour la forêt aléatoire, ous tentons ici d'améliorer les performances du modèle en sélectionnant plus finement les *features* selon leur importance dans la prédiction.

# %%
importances = pd.Series(
    xgb.feature_importances_,
    index=X_train.columns
).sort_values(ascending=False)

# %% [markdown]
# Les *chroma STFT max* sont encore moins importantes que pour la forêt aléatoire et les retirer ne change toujours que peu de choses aux résultats.

# %%
importances[280:]
# Out:
# mfcc_skew_17          0.001906
# mfcc_kurtosis_07      0.001901
# mfcc_skew_18          0.001889
# mfcc_kurtosis_12      0.001886
# mfcc_skew_19          0.001848
# tonnetz_skew_03       0.001828
# tonnetz_skew_04       0.001766
# tonnetz_skew_05       0.001726
# chroma_stft_max_03    0.000000
# chroma_stft_max_02    0.000000
# chroma_stft_max_01    0.000000
# chroma_stft_max_04    0.000000
# chroma_stft_max_08    0.000000
# chroma_stft_max_05    0.000000
# chroma_stft_max_06    0.000000
# chroma_stft_max_07    0.000000
# chroma_stft_max_12    0.000000
# chroma_stft_max_09    0.000000
# chroma_stft_max_10    0.000000
# chroma_stft_max_11    0.000000
# dtype: float32

# %% [markdown]
# On applique là encore un tri plus fin de l'importance des *features*.

# %%
from sklearn.inspection import permutation_importance

r = permutation_importance(
    xgb,
    X_test,
    y_test,
    n_repeats=5,
    scoring="f1_weighted",
    random_state=42
)

perm_importance = pd.Series(
    r.importances_mean,
    index=X_test.columns
).sort_values()

# %%
top_50_features=perm_importance[250:].index.tolist()
top_100_features=perm_importance[200:].index.tolist()
top_150_features=perm_importance[150:].index.tolist()

perm_importance
# Out:
# mfcc_skew_12                -0.000714
# mfcc_kurtosis_13            -0.000648
# chroma_stft_skew_05         -0.000637
# chroma_stft_skew_12         -0.000582
# chroma_stft_kurtosis_12     -0.000560
#                                ...
# spectral_contrast_skew_03    0.006253
# tonnetz_std_04               0.006720
# spectral_contrast_mean_04    0.007539
# spectral_contrast_mean_02    0.010918
# mfcc_max_04                  0.010977
# Length: 300, dtype: float64

# %% [markdown]
# Nous essayons comme pour la forêt aléatoire de nous en tenir à moins de *features* pour gagner en efficacité.

# %%
# 50 features
X=df_flat[top_50_features]
X_train_50, X_test_50, y_train_50, y_test_50 = train_test_split(X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)

# 100 features
X=df_flat[top_100_features]
X_train_100, X_test_100, y_train_100, y_test_100 = train_test_split(X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)

# 150 features
X=df_flat[top_150_features]
X_train_150, X_test_150, y_train_150, y_test_150 = train_test_split(X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)

# %% [markdown]
# L'observation faite pour la forêt aléatoire est encore plus vraie ici. Avec 150 *features* nous avons quasiment les mêmes résultats qu'avec le *dataframe* complet (0.690 contre 0.694 d'*accuracy*).

# %%
xgb = XGBClassifier(
    max_depth=10,
    min_child_weight=10,
    eval_metric="mlogloss",
    learning_rate=0.1,
    n_estimators=1000,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    early_stopping_rounds=50
)

xgb.fit(
    X_train_50,y_train_50, eval_set=[(X_test_50,y_test_50)],
    verbose=False # no print of the evaluation
)
y_pred_50 = xgb.predict(X_test_50)

xgb.fit(
    X_train_100,y_train_100, eval_set=[(X_test_100,y_test_100)],
    verbose=False
)
y_pred_100 = xgb.predict(X_test_100)

xgb.fit(
    X_train_150,y_train_150, eval_set=[(X_test_150,y_test_150)],
    verbose=False
)
y_pred_150 = xgb.predict(X_test_150)


print("Accuracy with top 50 features :", accuracy_score(y_test_50, y_pred_50))
print("Accuracy with top 100 features :", accuracy_score(y_test_100, y_pred_100))
print("Accuracy with top 150 features :", accuracy_score(y_test_150, y_pred_150))

y_pred_labels = le.inverse_transform(y_pred_150)
y_test_labels = le.inverse_transform(y_test_150)

print(classification_report(y_test_150, y_pred_150))
# Out:
# Accuracy with top 50 features : 0.6764112903225806
# Accuracy with top 100 features : 0.6895161290322581
# Accuracy with top 150 features : 0.6900201612903226
#               precision    recall  f1-score   support
#
#            0       0.85      0.79      0.82       246
#            1       0.66      0.72      0.69      1874
#            2       0.62      0.74      0.68      2122
#            3       0.67      0.62      0.65       561
#            4       0.74      0.68      0.71       710
#            5       0.52      0.32      0.40       416
#            6       0.81      0.42      0.56       278
#            7       0.71      0.19      0.30       114
#            8       0.94      0.92      0.93       111
#            9       0.62      0.05      0.09       101
#           10       0.47      0.15      0.23       466
#           11       0.76      0.85      0.80      2836
#           12       0.70      0.52      0.59        85
#
#     accuracy                           0.69      9920
#    macro avg       0.70      0.54      0.57      9920
# weighted avg       0.68      0.69      0.67      9920
