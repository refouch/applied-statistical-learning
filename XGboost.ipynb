# %% [markdown]
# # XGBoost
#
# Toujours avec des les features musicales agrégées Librosa, nous entraînons ici un modèle de classification *XGBoost*.
#
# ### I. Chargement, preprocessing des données et sélection des variables
#
# Comme pour la forêt aléatoire, nous reprenons le processus et les idées de sélection des variables développées dans *neural_net.ipynb*.

# %%
import numpy as np
import pandas as pd
from utils.load_data import fma_load


features = fma_load('data/fma_metadata/features.csv')
tracks = fma_load('data/fma_metadata/tracks.csv')

y = tracks['track','genre_top']

corr = features.corr()

threshold = 0.75

corr_matrix = corr.copy()

np.fill_diagonal(corr_matrix.values, 0) # Diagonal to zero

strong_corr = (corr_matrix.abs() > threshold)

pairs = []
for i in range(len(corr_matrix.columns)):
    for j in range(i+1, len(corr_matrix.columns)):
        if strong_corr.iloc[i, j]:
            pairs.append({
                "feature_1": corr_matrix.columns[i],
                "feature_2": corr_matrix.columns[j],
                "correlation": corr_matrix.iloc[i, j]
            })


features.drop(columns=['chroma_cqt','chroma_cens'],inplace=True)
features = features.loc[:, features.columns.get_level_values('statistics') != 'median']

features
# Out:
# feature    chroma_stft                                                    \
# statistics    kurtosis
# number              01        02        03        04        05        06
# track_id
# 2            -1.006041 -0.634076 -0.233752 -0.120917  0.004806  1.218982
# 3            -0.951502 -0.660734 -1.050015 -0.977441 -0.343043 -0.515404
# 5            -0.794551 -1.264806 -0.664387 -0.405196 -0.022688  0.014883
# 10            0.954931 -1.266404  0.030425 -0.646823  0.664217  0.082626
# 20           -0.048443 -0.543755 -1.336000 -0.410307 -0.684526 -0.960676
# ...                ...       ...       ...       ...       ...       ...
# 155316       -0.959207 -0.130793 -0.635587 -0.251981 -0.656534 -0.238574
# 155317       -0.965068 -0.679953 -1.051353 -0.852524 -0.872679 -0.740262
# 155318       -0.771414 -0.438261 -0.888968 -0.730804 -0.868208 -0.623147
# 155319       -0.984837 -0.198621 -0.923624 -0.825457 -1.035743 -0.919991
# 155320       -0.787214 -0.792066 -1.052318 -0.930889 -1.111142 -0.961365
#
# feature                                             ...   tonnetz            \
# statistics                                          ...       std
# number            07        08        09        10  ...        03        04
# track_id                                            ...
# 2           0.969103 -0.884986 -0.469190 -0.515475  ...  0.038974  0.054125
# 3          -0.973297 -1.261086 -1.132458 -0.953374  ...  0.051151  0.063831
# 5          -0.190766 -0.507027 -0.868905 -0.952605  ...  0.084997  0.040730
# 10         -1.241245  0.102074 -0.742071  0.670849  ...  0.088197  0.074358
# 20         -1.108473 -1.320151 -0.754329 -1.029887  ...  0.105521  0.095003
# ...              ...       ...       ...       ...  ...       ...       ...
# 155316     -0.372219 -0.661802 -0.297405 -0.533092  ...  0.102859  0.128410
# 155317     -0.737960 -1.060661 -1.029553 -0.949072  ...  0.135479  0.132964
# 155318     -0.855489 -0.950127 -0.725640 -0.694402  ...  0.089910  0.108324
# 155319     -0.655853 -0.887433 -0.398968 -0.233844  ...  0.092314  0.088311
# 155320     -0.890171 -0.987430 -0.638198 -1.095618  ...  0.099553  0.091421
#
# feature                               zcr                                \
# statistics                       kurtosis       max      mean       min
# number            05        06         01        01        01        01
# track_id
# 2           0.012226  0.012111   5.758890  0.459473  0.085629  0.000000
# 3           0.014212  0.017740   2.824694  0.466309  0.084578  0.000000
# 5           0.012691  0.014759   6.808415  0.375000  0.053114  0.000000
# 10          0.017952  0.013921  21.434212  0.452148  0.077515  0.000000
# 20          0.022492  0.021355  16.669037  0.469727  0.047225  0.000977
# ...              ...       ...        ...       ...       ...       ...
# 155316      0.022547  0.019816   4.448255  0.172852  0.028773  0.003906
# 155317      0.023548  0.026527   3.270612  0.196289  0.031116  0.002441
# 155318      0.017540  0.020471   2.356727  0.212891  0.038450  0.003418
# 155319      0.018328  0.017936   6.188604  0.167480  0.041480  0.004883
# 155320      0.020312  0.016794  21.756050  0.845215  0.075141  0.004395
#
# feature
# statistics      skew       std
# number            01        01
# track_id
# 2           2.089872  0.061448
# 3           1.716724  0.069330
# 5           2.193303  0.044861
# 10          3.542325  0.040800
# 20          3.189831  0.030993
# ...              ...       ...
# 155316      0.955388  0.012385
# 155317      1.283060  0.019059
# 155318      0.828569  0.017904
# 155319      1.818740  0.020133
# 155320      4.687204  0.137205
#
# [106574 rows x 300 columns]

# %%
from collections import Counter

df_flat = features.copy()
df_flat.columns = ['_'.join(col).strip() for col in df_flat.columns.values]

df_flat['genre_top'] = y

df_flat.dropna(inplace=True)

counts = Counter(df_flat['genre_top'])

rare_classes = [cls for cls, c in counts.items() if c < 400]

df_flat["genre_top_grouped"] = df_flat["genre_top"].replace(
    {cls: "Other" for cls in rare_classes}
)

df_flat
# Out:
# /tmp/ipykernel_206434/438632209.py:14: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   df_flat["genre_top_grouped"] = df_flat["genre_top"].replace(
#           chroma_stft_kurtosis_01  chroma_stft_kurtosis_02  \
# track_id
# 2                       -1.006041                -0.634076
# 3                       -0.951502                -0.660734
# 5                       -0.794551                -1.264806
# 10                       0.954931                -1.266404
# 134                     -0.972450                -1.047674
# ...                           ...                      ...
# 155315                  -0.931622                -0.823569
# 155316                  -0.959207                -0.130793
# 155317                  -0.965068                -0.679953
# 155318                  -0.771414                -0.438261
# 155319                  -0.984837                -0.198621
#
#           chroma_stft_kurtosis_03  chroma_stft_kurtosis_04  \
# track_id
# 2                       -0.233752                -0.120917
# 3                       -1.050015                -0.977441
# 5                       -0.664387                -0.405196
# 10                       0.030425                -0.646823
# 134                     -1.312579                -1.120184
# ...                           ...                      ...
# 155315                  -1.235423                -1.213406
# 155316                  -0.635587                -0.251981
# 155317                  -1.051353                -0.852524
# 155318                  -0.888968                -0.730804
# 155319                  -0.923624                -0.825457
#
#           chroma_stft_kurtosis_05  chroma_stft_kurtosis_06  \
# track_id
# 2                        0.004806                 1.218982
# 3                       -0.343043                -0.515404
# 5                       -0.022688                 0.014883
# 10                       0.664217                 0.082626
# 134                     -1.280836                -1.215888
# ...                           ...                      ...
# 155315                  -0.999892                -0.672000
# 155316                  -0.656534                -0.238574
# 155317                  -0.872679                -0.740262
# 155318                  -0.868208                -0.623147
# 155319                  -1.035743                -0.919991
#
#           chroma_stft_kurtosis_07  chroma_stft_kurtosis_08  \
# track_id
# 2                        0.969103                -0.884986
# 3                       -0.973297                -1.261086
# 5                       -0.190766                -0.507027
# 10                      -1.241245                 0.102074
# 134                     -1.006120                -0.915774
# ...                           ...                      ...
# 155315                  -1.219753                -1.381937
# 155316                  -0.372219                -0.661802
# 155317                  -0.737960                -1.060661
# 155318                  -0.855489                -0.950127
# 155319                  -0.655853                -0.887433
#
#           chroma_stft_kurtosis_09  chroma_stft_kurtosis_10  ...  \
# track_id                                                    ...
# 2                       -0.469190                -0.515475  ...
# 3                       -1.132458                -0.953374  ...
# 5                       -0.868905                -0.952605  ...
# 10                      -0.742071                 0.670849  ...
# 134                     -0.781248                -1.012533  ...
# ...                           ...                      ...  ...
# 155315                  -1.270755                -1.129524  ...
# 155316                  -0.297405                -0.533092  ...
# 155317                  -1.029553                -0.949072  ...
# 155318                  -0.725640                -0.694402  ...
# 155319                  -0.398968                -0.233844  ...
#
#           tonnetz_std_05  tonnetz_std_06  zcr_kurtosis_01  zcr_max_01  \
# track_id
# 2               0.012226        0.012111         5.758890    0.459473
# 3               0.014212        0.017740         2.824694    0.466309
# 5               0.012691        0.014759         6.808415    0.375000
# 10              0.017952        0.013921        21.434212    0.452148
# 134             0.016322        0.015819         4.731087    0.419434
# ...                  ...             ...              ...         ...
# 155315          0.016631        0.014705         6.947788    0.188477
# 155316          0.022547        0.019816         4.448255    0.172852
# 155317          0.023548        0.026527         3.270612    0.196289
# 155318          0.017540        0.020471         2.356727    0.212891
# 155319          0.018328        0.017936         6.188604    0.167480
#
#           zcr_mean_01  zcr_min_01  zcr_skew_01  zcr_std_01  genre_top  \
# track_id
# 2            0.085629    0.000000     2.089872    0.061448    Hip-Hop
# 3            0.084578    0.000000     1.716724    0.069330    Hip-Hop
# 5            0.053114    0.000000     2.193303    0.044861    Hip-Hop
# 10           0.077515    0.000000     3.542325    0.040800        Pop
# 134          0.064370    0.000000     1.806106    0.054623    Hip-Hop
# ...               ...         ...          ...         ...        ...
# 155315       0.037708    0.002930     1.764233    0.018679       Rock
# 155316       0.028773    0.003906     0.955388    0.012385       Rock
# 155317       0.031116    0.002441     1.283060    0.019059       Rock
# 155318       0.038450    0.003418     0.828569    0.017904       Rock
# 155319       0.041480    0.004883     1.818740    0.020133       Rock
#
#           genre_top_grouped
# track_id
# 2                   Hip-Hop
# 3                   Hip-Hop
# 5                   Hip-Hop
# 10                      Pop
# 134                 Hip-Hop
# ...                     ...
# 155315                 Rock
# 155316                 Rock
# 155317                 Rock
# 155318                 Rock
# 155319                 Rock
#
# [49598 rows x 302 columns]

# %% [markdown]
# ## II. Création du XGBoost
#
# On retrace ici les choix d'entraînement de notre modèle *XGBoost*.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder


y = df_flat["genre_top_grouped"].dropna()

X = df_flat.drop(["genre_top","genre_top_grouped"],axis=1).loc[y.index]

le = LabelEncoder()
y_encoded = le.fit_transform(y) #necessary for xgb
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)

# %% [markdown]
# Comme pour la forêt aléatoire, afin d'identifier rapidemment les meilleurs hyper-paramètres, on utilise `RandomizedSearchCV` mais cette fois-ci sur 3 *folds* pour gagner du temps de calcul (le modèle étant plus complexe qu'une forêt aléatoire).
#
# (De même, ce code prend longtemps à tourner, nous suggérons de sauter les deux cellules suviantes.)

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import f1_score, make_scorer

f1_weighted = make_scorer(f1_score, average="weighted")

param_dist = {
    "max_depth": [4, 6, 8, 10],
    "min_child_weight": [1, 5, 10],
    "subsample": [0.7, 0.8, 1.0],
    "colsample_bytree": [0.7, 0.8, 1.0],
}

cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

search = RandomizedSearchCV(
    xgb,
    param_distributions=param_dist,
    n_iter=20,
    scoring=f1_weighted,
    cv=cv,
    verbose=2,
    n_jobs=-1
)

search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [CV] END colsample_bytree=0.8, max_depth=4, min_child_weight=10, subsample=0.7; total time= 4.5min
# [CV] END colsample_bytree=0.8, max_depth=4, min_child_weight=10, subsample=0.7; total time= 4.6min
# [CV] END colsample_bytree=0.8, max_depth=4, min_child_weight=10, subsample=0.7; total time= 4.7min
# [CV] END colsample_bytree=1.0, max_depth=8, min_child_weight=10, subsample=0.7; total time=10.2min
# [CV] END colsample_bytree=1.0, max_depth=8, min_child_weight=10, subsample=0.7; total time=10.6min
# [CV] END colsample_bytree=1.0, max_depth=8, min_child_weight=10, subsample=0.7; total time=10.6min
# [CV] END colsample_bytree=1.0, max_depth=8, min_child_weight=5, subsample=1.0; total time=12.2min
# [CV] END colsample_bytree=1.0, max_depth=8, min_child_weight=5, subsample=1.0; total time=12.2min
# [CV] END colsample_bytree=0.7, max_depth=6, min_child_weight=5, subsample=1.0; total time= 7.8min
# [CV] END colsample_bytree=1.0, max_depth=8, min_child_weight=5, subsample=1.0; total time=12.6min
# [CV] END colsample_bytree=0.7, max_depth=6, min_child_weight=5, subsample=1.0; total time= 8.4min
# [CV] END colsample_bytree=0.7, max_depth=6, min_child_weight=5, subsample=1.0; total time= 8.6min
# [CV] END colsample_bytree=1.0, max_depth=10, min_child_weight=5, subsample=0.8; total time=13.9min
# [CV] END colsample_bytree=1.0, max_depth=10, min_child_weight=5, subsample=0.8; total time=14.2min
# [CV] END colsample_bytree=1.0, max_depth=10, min_child_weight=5, subsample=0.8; total time=14.2min
# [CV] END colsample_bytree=0.7, max_depth=10, min_child_weight=1, subsample=0.7; total time=17.2min
# [CV] END colsample_bytree=0.7, max_depth=10, min_child_weight=1, subsample=0.7; total time=17.4min
# [CV] END colsample_bytree=1.0, max_depth=4, min_child_weight=1, subsample=1.0; total time= 5.5min
# [CV] END colsample_bytree=0.7, max_depth=10, min_child_weight=1, subsample=0.7; total time=18.2min
# [CV] END colsample_bytree=1.0, max_depth=4, min_child_weight=1, subsample=1.0; total time= 5.4min
# [CV] END colsample_bytree=1.0, max_depth=4, min_child_weight=1, subsample=1.0; total time= 5.3min
# [CV] END colsample_bytree=1.0, max_depth=4, min_child_weight=10, subsample=0.8; total time= 4.7min
# [CV] END colsample_bytree=1.0, max_depth=4, min_child_weight=10, subsample=0.8; total time= 5.0min
# [CV] END colsample_bytree=1.0, max_depth=4, min_child_weight=10, subsample=0.8; total time= 5.4min
# [CV] END colsample_bytree=0.7, max_depth=10, min_child_weight=10, subsample=0.7; total time=10.2min
# [CV] END colsample_bytree=0.7, max_depth=10, min_child_weight=10, subsample=0.7; total time=10.5min
# [CV] END colsample_bytree=0.7, max_depth=10, min_child_weight=10, subsample=0.7; total time=10.9min
# [CV] END colsample_bytree=1.0, max_depth=4, min_child_weight=10, subsample=0.7; total time= 4.7min
# [CV] END colsample_bytree=1.0, max_depth=4, min_child_weight=10, subsample=0.7; total time= 4.9min
# [CV] END colsample_bytree=1.0, max_depth=4, min_child_weight=10, subsample=0.7; total time= 5.4min
# [CV] END colsample_bytree=1.0, max_depth=4, min_child_weight=5, subsample=0.7; total time= 5.0min
# [CV] END colsample_bytree=0.8, max_depth=8, min_child_weight=1, subsample=0.8; total time=14.6min
# [CV] END colsample_bytree=0.8, max_depth=8, min_child_weight=1, subsample=0.8; total time=14.9min
# [CV] END colsample_bytree=0.8, max_depth=8, min_child_weight=1, subsample=0.8; total time=15.4min
# [CV] END colsample_bytree=1.0, max_depth=4, min_child_weight=5, subsample=0.7; total time= 5.7min
# [CV] END colsample_bytree=1.0, max_depth=4, min_child_weight=5, subsample=0.7; total time= 5.3min
# [CV] END colsample_bytree=0.7, max_depth=6, min_child_weight=1, subsample=0.8; total time=10.2min
# [CV] END colsample_bytree=0.7, max_depth=6, min_child_weight=1, subsample=0.8; total time=10.4min
# [CV] END colsample_bytree=0.7, max_depth=10, min_child_weight=10, subsample=1.0; total time=11.4min
# [CV] END colsample_bytree=0.7, max_depth=10, min_child_weight=10, subsample=1.0; total time=11.1min
# [CV] END colsample_bytree=0.7, max_depth=6, min_child_weight=1, subsample=0.8; total time=10.6min
# [CV] END colsample_bytree=0.7, max_depth=10, min_child_weight=10, subsample=1.0; total time=11.6min
# [CV] END colsample_bytree=0.8, max_depth=10, min_child_weight=10, subsample=0.8; total time=10.7min
# [CV] END colsample_bytree=0.8, max_depth=10, min_child_weight=10, subsample=0.8; total time=12.0min
# [CV] END colsample_bytree=0.8, max_depth=10, min_child_weight=10, subsample=0.8; total time=11.6min
# [CV] END colsample_bytree=0.7, max_depth=4, min_child_weight=5, subsample=0.7; total time= 4.9min
# [CV] END colsample_bytree=0.7, max_depth=4, min_child_weight=5, subsample=0.7; total time= 4.7min
# [CV] END colsample_bytree=0.7, max_depth=4, min_child_weight=5, subsample=0.7; total time= 4.9min
# [CV] END colsample_bytree=0.8, max_depth=8, min_child_weight=5, subsample=0.7; total time=10.8min
# [CV] END colsample_bytree=0.8, max_depth=8, min_child_weight=5, subsample=0.7; total time=10.7min
# [CV] END colsample_bytree=1.0, max_depth=10, min_child_weight=5, subsample=1.0; total time=13.9min
# [CV] END colsample_bytree=0.8, max_depth=8, min_child_weight=5, subsample=0.7; total time=11.0min
# [CV] END colsample_bytree=1.0, max_depth=10, min_child_weight=5, subsample=1.0; total time=14.5min
# [CV] END colsample_bytree=1.0, max_depth=10, min_child_weight=5, subsample=1.0; total time=14.5min
# [CV] END colsample_bytree=0.8, max_depth=6, min_child_weight=1, subsample=0.8; total time=10.3min
# [CV] END colsample_bytree=0.8, max_depth=6, min_child_weight=1, subsample=0.8; total time= 9.5min
# [CV] END colsample_bytree=0.8, max_depth=6, min_child_weight=1, subsample=0.8; total time=10.0min
# [CV] END colsample_bytree=0.8, max_depth=10, min_child_weight=1, subsample=0.7; total time=17.3min
# [CV] END colsample_bytree=0.8, max_depth=10, min_child_weight=1, subsample=0.7; total time=17.6min
# [CV] END colsample_bytree=0.8, max_depth=10, min_child_weight=1, subsample=0.7; total time=16.8min
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=3, random_state=42, shuffle=True),
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=0.8, device=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric='mlogloss',
#                                            feature_types=None,
#                                            feature_weights=None, gamma=None...
#                                            min_child_weight=None, missing=nan,
#                                            monotone_constraints=None,
#                                            multi_strategy=None,
#                                            n_estimators=500, n_jobs=None,
#                                            num_parallel_tree=None, ...),
#                    n_iter=20, n_jobs=-1,
#                    param_distributions={'colsample_bytree': [0.7, 0.8, 1.0],
#                                         'max_depth': [4, 6, 8, 10],
#                                         'min_child_weight': [1, 5, 10],
#                                         'subsample': [0.7, 0.8, 1.0]},
#                    scoring=make_scorer(f1_score, response_method='predict', average=weighted),
#                    verbose=2)

# %%
print("Best params:", search.best_params_)
print("Best CV F1:", search.best_score_)
# Out:
# Best params: {'subsample': 0.8, 'min_child_weight': 10, 'max_depth': 10, 'colsample_bytree': 0.8}
# Best CV F1: 0.6735860490211225

# %%
from xgboost import XGBClassifier

xgb = XGBClassifier(
    max_depth=10,
    min_child_weight=10,
    n_estimators=500,
    colsample_bytree=0.8,
    learning_rate=0.1,
    eval_metric='mlogloss',
    use_label_encoder=False,
    random_state=42
)

xgb.fit(
    X_train, y_train,
    eval_set=[(X_test, y_test)],
    verbose=True
)
# Out:
# /opt/python/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [16:16:39] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [0]	validation_0-mlogloss:2.27761
# [1]	validation_0-mlogloss:2.13880
# [2]	validation_0-mlogloss:2.02804
# [3]	validation_0-mlogloss:1.93622
# [4]	validation_0-mlogloss:1.85606
# [5]	validation_0-mlogloss:1.78743
# [6]	validation_0-mlogloss:1.72706
# [7]	validation_0-mlogloss:1.67404
# [8]	validation_0-mlogloss:1.62632
# [9]	validation_0-mlogloss:1.58336
# [10]	validation_0-mlogloss:1.54442
# [11]	validation_0-mlogloss:1.50918
# [12]	validation_0-mlogloss:1.47671
# [13]	validation_0-mlogloss:1.44688
# [14]	validation_0-mlogloss:1.42003
# [15]	validation_0-mlogloss:1.39509
# [16]	validation_0-mlogloss:1.37229
# [17]	validation_0-mlogloss:1.35082
# [18]	validation_0-mlogloss:1.33058
# [19]	validation_0-mlogloss:1.31216
# [20]	validation_0-mlogloss:1.29539
# [21]	validation_0-mlogloss:1.27928
# [22]	validation_0-mlogloss:1.26401
# [23]	validation_0-mlogloss:1.24970
# [24]	validation_0-mlogloss:1.23696
# [25]	validation_0-mlogloss:1.22497
# [26]	validation_0-mlogloss:1.21324
# [27]	validation_0-mlogloss:1.20295
# [28]	validation_0-mlogloss:1.19334
# [29]	validation_0-mlogloss:1.18398
# [30]	validation_0-mlogloss:1.17459
# [31]	validation_0-mlogloss:1.16637
# [32]	validation_0-mlogloss:1.15856
# [33]	validation_0-mlogloss:1.15116
# [34]	validation_0-mlogloss:1.14371
# [35]	validation_0-mlogloss:1.13690
# [36]	validation_0-mlogloss:1.13023
# [37]	validation_0-mlogloss:1.12423
# [38]	validation_0-mlogloss:1.11873
# [39]	validation_0-mlogloss:1.11344
# [40]	validation_0-mlogloss:1.10834
# [41]	validation_0-mlogloss:1.10339
# [42]	validation_0-mlogloss:1.09892
# [43]	validation_0-mlogloss:1.09422
# [44]	validation_0-mlogloss:1.09017
# [45]	validation_0-mlogloss:1.08550
# [46]	validation_0-mlogloss:1.08159
# [47]	validation_0-mlogloss:1.07782
# [48]	validation_0-mlogloss:1.07381
# [49]	validation_0-mlogloss:1.07020
# [50]	validation_0-mlogloss:1.06671
# [51]	validation_0-mlogloss:1.06339
# [52]	validation_0-mlogloss:1.06019
# [53]	validation_0-mlogloss:1.05709
# [54]	validation_0-mlogloss:1.05408
# [55]	validation_0-mlogloss:1.05124
# [56]	validation_0-mlogloss:1.04832
# [57]	validation_0-mlogloss:1.04590
# [58]	validation_0-mlogloss:1.04330
# [59]	validation_0-mlogloss:1.04106
# [60]	validation_0-mlogloss:1.03861
# [61]	validation_0-mlogloss:1.03627
# [62]	validation_0-mlogloss:1.03383
# [63]	validation_0-mlogloss:1.03198
# [64]	validation_0-mlogloss:1.02990
# [65]	validation_0-mlogloss:1.02762
# [66]	validation_0-mlogloss:1.02571
# [67]	validation_0-mlogloss:1.02401
# [68]	validation_0-mlogloss:1.02243
# [69]	validation_0-mlogloss:1.02094
# [70]	validation_0-mlogloss:1.01909
# [71]	validation_0-mlogloss:1.01755
# [72]	validation_0-mlogloss:1.01592
# [73]	validation_0-mlogloss:1.01483
# [74]	validation_0-mlogloss:1.01348
# [75]	validation_0-mlogloss:1.01202
# [76]	validation_0-mlogloss:1.01085
# [77]	validation_0-mlogloss:1.00965
# [78]	validation_0-mlogloss:1.00847
# [79]	validation_0-mlogloss:1.00700
# [80]	validation_0-mlogloss:1.00576
# [81]	validation_0-mlogloss:1.00469
# [82]	validation_0-mlogloss:1.00348
# [83]	validation_0-mlogloss:1.00228
# [84]	validation_0-mlogloss:1.00117
# [85]	validation_0-mlogloss:1.00018
# [86]	validation_0-mlogloss:0.99937
# [87]	validation_0-mlogloss:0.99823
# [88]	validation_0-mlogloss:0.99712
# [89]	validation_0-mlogloss:0.99597
# [90]	validation_0-mlogloss:0.99508
# [91]	validation_0-mlogloss:0.99395
# [92]	validation_0-mlogloss:0.99297
# [93]	validation_0-mlogloss:0.99192
# [94]	validation_0-mlogloss:0.99062
# [95]	validation_0-mlogloss:0.98968
# [96]	validation_0-mlogloss:0.98919
# [97]	validation_0-mlogloss:0.98842
# [98]	validation_0-mlogloss:0.98783
# [99]	validation_0-mlogloss:0.98717
# [100]	validation_0-mlogloss:0.98647
# [101]	validation_0-mlogloss:0.98578
# [102]	validation_0-mlogloss:0.98491
# [103]	validation_0-mlogloss:0.98425
# [104]	validation_0-mlogloss:0.98354
# [105]	validation_0-mlogloss:0.98277
# [106]	validation_0-mlogloss:0.98211
# [107]	validation_0-mlogloss:0.98140
# [108]	validation_0-mlogloss:0.98095
# [109]	validation_0-mlogloss:0.98046
# [110]	validation_0-mlogloss:0.97991
# [111]	validation_0-mlogloss:0.97921
# [112]	validation_0-mlogloss:0.97868
# [113]	validation_0-mlogloss:0.97815
# [114]	validation_0-mlogloss:0.97784
# [115]	validation_0-mlogloss:0.97737
# [116]	validation_0-mlogloss:0.97687
# [117]	validation_0-mlogloss:0.97653
# [118]	validation_0-mlogloss:0.97605
# [119]	validation_0-mlogloss:0.97566
# [120]	validation_0-mlogloss:0.97544
# [121]	validation_0-mlogloss:0.97490
# [122]	validation_0-mlogloss:0.97438
# [123]	validation_0-mlogloss:0.97383
# [124]	validation_0-mlogloss:0.97320
# [125]	validation_0-mlogloss:0.97273
# [126]	validation_0-mlogloss:0.97208
# [127]	validation_0-mlogloss:0.97153
# [128]	validation_0-mlogloss:0.97128
# [129]	validation_0-mlogloss:0.97093
# [130]	validation_0-mlogloss:0.97045
# [131]	validation_0-mlogloss:0.97016
# [132]	validation_0-mlogloss:0.96982
# [133]	validation_0-mlogloss:0.96931
# [134]	validation_0-mlogloss:0.96895
# [135]	validation_0-mlogloss:0.96873
# [136]	validation_0-mlogloss:0.96863
# [137]	validation_0-mlogloss:0.96822
# [138]	validation_0-mlogloss:0.96807
# [139]	validation_0-mlogloss:0.96786
# [140]	validation_0-mlogloss:0.96754
# [141]	validation_0-mlogloss:0.96728
# [142]	validation_0-mlogloss:0.96692
# [143]	validation_0-mlogloss:0.96661
# [144]	validation_0-mlogloss:0.96620
# [145]	validation_0-mlogloss:0.96581
# [146]	validation_0-mlogloss:0.96552
# [147]	validation_0-mlogloss:0.96537
# [148]	validation_0-mlogloss:0.96504
# [149]	validation_0-mlogloss:0.96485
# [150]	validation_0-mlogloss:0.96451
# [151]	validation_0-mlogloss:0.96434
# [152]	validation_0-mlogloss:0.96405
# [153]	validation_0-mlogloss:0.96388
# [154]	validation_0-mlogloss:0.96339
# [155]	validation_0-mlogloss:0.96334
# [156]	validation_0-mlogloss:0.96316
# [157]	validation_0-mlogloss:0.96307
# [158]	validation_0-mlogloss:0.96316
# [159]	validation_0-mlogloss:0.96310
# [160]	validation_0-mlogloss:0.96299
# [161]	validation_0-mlogloss:0.96254
# [162]	validation_0-mlogloss:0.96240
# [163]	validation_0-mlogloss:0.96240
# [164]	validation_0-mlogloss:0.96234
# [165]	validation_0-mlogloss:0.96234
# [166]	validation_0-mlogloss:0.96215
# [167]	validation_0-mlogloss:0.96188
# [168]	validation_0-mlogloss:0.96186
# [169]	validation_0-mlogloss:0.96167
# [170]	validation_0-mlogloss:0.96147
# [171]	validation_0-mlogloss:0.96131
# [172]	validation_0-mlogloss:0.96122
# [173]	validation_0-mlogloss:0.96106
# [174]	validation_0-mlogloss:0.96100
# [175]	validation_0-mlogloss:0.96107
# [176]	validation_0-mlogloss:0.96095
# [177]	validation_0-mlogloss:0.96093
# [178]	validation_0-mlogloss:0.96083
# [179]	validation_0-mlogloss:0.96078
# [180]	validation_0-mlogloss:0.96061
# [181]	validation_0-mlogloss:0.96050
# [182]	validation_0-mlogloss:0.96038
# [183]	validation_0-mlogloss:0.96046
# [184]	validation_0-mlogloss:0.96033
# [185]	validation_0-mlogloss:0.96038
# [186]	validation_0-mlogloss:0.96014
# [187]	validation_0-mlogloss:0.96005
# [188]	validation_0-mlogloss:0.96008
# [189]	validation_0-mlogloss:0.95991
# [190]	validation_0-mlogloss:0.95986
# [191]	validation_0-mlogloss:0.95996
# [192]	validation_0-mlogloss:0.96005
# [193]	validation_0-mlogloss:0.95993
# [194]	validation_0-mlogloss:0.95978
# [195]	validation_0-mlogloss:0.95966
# [196]	validation_0-mlogloss:0.95944
# [197]	validation_0-mlogloss:0.95948
# [198]	validation_0-mlogloss:0.95943
# [199]	validation_0-mlogloss:0.95950
# [200]	validation_0-mlogloss:0.95934
# [201]	validation_0-mlogloss:0.95908
# [202]	validation_0-mlogloss:0.95884
# [203]	validation_0-mlogloss:0.95889
# [204]	validation_0-mlogloss:0.95887
# [205]	validation_0-mlogloss:0.95892
# [206]	validation_0-mlogloss:0.95883
# [207]	validation_0-mlogloss:0.95877
# [208]	validation_0-mlogloss:0.95865
# [209]	validation_0-mlogloss:0.95855
# [210]	validation_0-mlogloss:0.95846
# [211]	validation_0-mlogloss:0.95835
# [212]	validation_0-mlogloss:0.95833
# [213]	validation_0-mlogloss:0.95834
# [214]	validation_0-mlogloss:0.95825
# [215]	validation_0-mlogloss:0.95825
# [216]	validation_0-mlogloss:0.95830
# [217]	validation_0-mlogloss:0.95821
# [218]	validation_0-mlogloss:0.95832
# [219]	validation_0-mlogloss:0.95825
# [220]	validation_0-mlogloss:0.95836
# [221]	validation_0-mlogloss:0.95839
# [222]	validation_0-mlogloss:0.95829
# [223]	validation_0-mlogloss:0.95820
# [224]	validation_0-mlogloss:0.95813
# [225]	validation_0-mlogloss:0.95819
# [226]	validation_0-mlogloss:0.95802
# [227]	validation_0-mlogloss:0.95797
# [228]	validation_0-mlogloss:0.95795
# [229]	validation_0-mlogloss:0.95787
# [230]	validation_0-mlogloss:0.95788
# [231]	validation_0-mlogloss:0.95788
# [232]	validation_0-mlogloss:0.95786
# [233]	validation_0-mlogloss:0.95786
# [234]	validation_0-mlogloss:0.95785
# [235]	validation_0-mlogloss:0.95785
# [236]	validation_0-mlogloss:0.95774
# [237]	validation_0-mlogloss:0.95778
# [238]	validation_0-mlogloss:0.95770
# [239]	validation_0-mlogloss:0.95763
# [240]	validation_0-mlogloss:0.95755
# [241]	validation_0-mlogloss:0.95756
# [242]	validation_0-mlogloss:0.95757
# [243]	validation_0-mlogloss:0.95750
# [244]	validation_0-mlogloss:0.95758
# [245]	validation_0-mlogloss:0.95754
# [246]	validation_0-mlogloss:0.95758
# [247]	validation_0-mlogloss:0.95762
# [248]	validation_0-mlogloss:0.95751
# [249]	validation_0-mlogloss:0.95746
# [250]	validation_0-mlogloss:0.95754
# [251]	validation_0-mlogloss:0.95747
# [252]	validation_0-mlogloss:0.95766
# [253]	validation_0-mlogloss:0.95759
# [254]	validation_0-mlogloss:0.95770
# [255]	validation_0-mlogloss:0.95768
# [256]	validation_0-mlogloss:0.95765
# [257]	validation_0-mlogloss:0.95762
# [258]	validation_0-mlogloss:0.95767
# [259]	validation_0-mlogloss:0.95784
# [260]	validation_0-mlogloss:0.95778
# [261]	validation_0-mlogloss:0.95774
# [262]	validation_0-mlogloss:0.95779
# [263]	validation_0-mlogloss:0.95793
# [264]	validation_0-mlogloss:0.95800
# [265]	validation_0-mlogloss:0.95815
# [266]	validation_0-mlogloss:0.95816
# [267]	validation_0-mlogloss:0.95835
# [268]	validation_0-mlogloss:0.95814
# [269]	validation_0-mlogloss:0.95808
# [270]	validation_0-mlogloss:0.95822
# [271]	validation_0-mlogloss:0.95822
# [272]	validation_0-mlogloss:0.95824
# [273]	validation_0-mlogloss:0.95817
# [274]	validation_0-mlogloss:0.95830
# [275]	validation_0-mlogloss:0.95846
# [276]	validation_0-mlogloss:0.95854
# [277]	validation_0-mlogloss:0.95852
# [278]	validation_0-mlogloss:0.95852
# [279]	validation_0-mlogloss:0.95873
# [280]	validation_0-mlogloss:0.95883
# [281]	validation_0-mlogloss:0.95893
# [282]	validation_0-mlogloss:0.95897
# [283]	validation_0-mlogloss:0.95909
# [284]	validation_0-mlogloss:0.95900
# [285]	validation_0-mlogloss:0.95912
# [286]	validation_0-mlogloss:0.95914
# [287]	validation_0-mlogloss:0.95919
# [288]	validation_0-mlogloss:0.95936
# [289]	validation_0-mlogloss:0.95947
# [290]	validation_0-mlogloss:0.95949
# [291]	validation_0-mlogloss:0.95963
# [292]	validation_0-mlogloss:0.95967
# [293]	validation_0-mlogloss:0.95974
# [294]	validation_0-mlogloss:0.95973
# [295]	validation_0-mlogloss:0.95978
# [296]	validation_0-mlogloss:0.96009
# [297]	validation_0-mlogloss:0.96012
# [298]	validation_0-mlogloss:0.96011
# [299]	validation_0-mlogloss:0.96005
# [300]	validation_0-mlogloss:0.96016
# [301]	validation_0-mlogloss:0.96010
# [302]	validation_0-mlogloss:0.96018
# [303]	validation_0-mlogloss:0.96026
# [304]	validation_0-mlogloss:0.96027
# [305]	validation_0-mlogloss:0.96033
# [306]	validation_0-mlogloss:0.96034
# [307]	validation_0-mlogloss:0.96038
# [308]	validation_0-mlogloss:0.96059
# [309]	validation_0-mlogloss:0.96061
# [310]	validation_0-mlogloss:0.96067
# [311]	validation_0-mlogloss:0.96085
# [312]	validation_0-mlogloss:0.96085
# [313]	validation_0-mlogloss:0.96103
# [314]	validation_0-mlogloss:0.96112
# [315]	validation_0-mlogloss:0.96125
# [316]	validation_0-mlogloss:0.96138
# [317]	validation_0-mlogloss:0.96160
# [318]	validation_0-mlogloss:0.96162
# [319]	validation_0-mlogloss:0.96157
# [320]	validation_0-mlogloss:0.96148
# [321]	validation_0-mlogloss:0.96150
# [322]	validation_0-mlogloss:0.96149
# [323]	validation_0-mlogloss:0.96165
# [324]	validation_0-mlogloss:0.96163
# [325]	validation_0-mlogloss:0.96180
# [326]	validation_0-mlogloss:0.96192
# [327]	validation_0-mlogloss:0.96203
# [328]	validation_0-mlogloss:0.96211
# [329]	validation_0-mlogloss:0.96212
# [330]	validation_0-mlogloss:0.96208
# [331]	validation_0-mlogloss:0.96219
# [332]	validation_0-mlogloss:0.96225
# [333]	validation_0-mlogloss:0.96222
# [334]	validation_0-mlogloss:0.96234
# [335]	validation_0-mlogloss:0.96248
# [336]	validation_0-mlogloss:0.96256
# [337]	validation_0-mlogloss:0.96274
# [338]	validation_0-mlogloss:0.96277
# [339]	validation_0-mlogloss:0.96257
# [340]	validation_0-mlogloss:0.96256
# [341]	validation_0-mlogloss:0.96267
# [342]	validation_0-mlogloss:0.96275
# [343]	validation_0-mlogloss:0.96300
# [344]	validation_0-mlogloss:0.96303
# [345]	validation_0-mlogloss:0.96321
# [346]	validation_0-mlogloss:0.96332
# [347]	validation_0-mlogloss:0.96334
# [348]	validation_0-mlogloss:0.96343
# [349]	validation_0-mlogloss:0.96351
# [350]	validation_0-mlogloss:0.96359
# [351]	validation_0-mlogloss:0.96356
# [352]	validation_0-mlogloss:0.96348
# [353]	validation_0-mlogloss:0.96357
# [354]	validation_0-mlogloss:0.96363
# [355]	validation_0-mlogloss:0.96375
# [356]	validation_0-mlogloss:0.96382
# [357]	validation_0-mlogloss:0.96379
# [358]	validation_0-mlogloss:0.96385
# [359]	validation_0-mlogloss:0.96383
# [360]	validation_0-mlogloss:0.96396
# [361]	validation_0-mlogloss:0.96398
# [362]	validation_0-mlogloss:0.96396
# [363]	validation_0-mlogloss:0.96405
# [364]	validation_0-mlogloss:0.96407
# [365]	validation_0-mlogloss:0.96414
# [366]	validation_0-mlogloss:0.96425
# [367]	validation_0-mlogloss:0.96428
# [368]	validation_0-mlogloss:0.96429
# [369]	validation_0-mlogloss:0.96435
# [370]	validation_0-mlogloss:0.96448
# [371]	validation_0-mlogloss:0.96454
# [372]	validation_0-mlogloss:0.96454
# [373]	validation_0-mlogloss:0.96473
# [374]	validation_0-mlogloss:0.96477
# [375]	validation_0-mlogloss:0.96498
# [376]	validation_0-mlogloss:0.96513
# [377]	validation_0-mlogloss:0.96529
# [378]	validation_0-mlogloss:0.96531
# [379]	validation_0-mlogloss:0.96539
# [380]	validation_0-mlogloss:0.96545
# [381]	validation_0-mlogloss:0.96554
# [382]	validation_0-mlogloss:0.96550
# [383]	validation_0-mlogloss:0.96554
# [384]	validation_0-mlogloss:0.96562
# [385]	validation_0-mlogloss:0.96570
# [386]	validation_0-mlogloss:0.96577
# [387]	validation_0-mlogloss:0.96580
# [388]	validation_0-mlogloss:0.96593
# [389]	validation_0-mlogloss:0.96594
# [390]	validation_0-mlogloss:0.96607
# [391]	validation_0-mlogloss:0.96619
# [392]	validation_0-mlogloss:0.96640
# [393]	validation_0-mlogloss:0.96645
# [394]	validation_0-mlogloss:0.96657
# [395]	validation_0-mlogloss:0.96667
# [396]	validation_0-mlogloss:0.96671
# [397]	validation_0-mlogloss:0.96670
# [398]	validation_0-mlogloss:0.96679
# [399]	validation_0-mlogloss:0.96683
# [400]	validation_0-mlogloss:0.96679
# [401]	validation_0-mlogloss:0.96679
# [402]	validation_0-mlogloss:0.96679
# [403]	validation_0-mlogloss:0.96687
# [404]	validation_0-mlogloss:0.96705
# [405]	validation_0-mlogloss:0.96713
# [406]	validation_0-mlogloss:0.96723
# [407]	validation_0-mlogloss:0.96722
# [408]	validation_0-mlogloss:0.96733
# [409]	validation_0-mlogloss:0.96740
# [410]	validation_0-mlogloss:0.96755
# [411]	validation_0-mlogloss:0.96763
# [412]	validation_0-mlogloss:0.96767
# [413]	validation_0-mlogloss:0.96778
# [414]	validation_0-mlogloss:0.96786
# [415]	validation_0-mlogloss:0.96796
# [416]	validation_0-mlogloss:0.96796
# [417]	validation_0-mlogloss:0.96796
# [418]	validation_0-mlogloss:0.96807
# [419]	validation_0-mlogloss:0.96818
# [420]	validation_0-mlogloss:0.96831
# [421]	validation_0-mlogloss:0.96836
# [422]	validation_0-mlogloss:0.96836
# [423]	validation_0-mlogloss:0.96838
# [424]	validation_0-mlogloss:0.96849
# [425]	validation_0-mlogloss:0.96864
# [426]	validation_0-mlogloss:0.96877
# [427]	validation_0-mlogloss:0.96890
# [428]	validation_0-mlogloss:0.96900
# [429]	validation_0-mlogloss:0.96903
# [430]	validation_0-mlogloss:0.96915
# [431]	validation_0-mlogloss:0.96914
# [432]	validation_0-mlogloss:0.96918
# [433]	validation_0-mlogloss:0.96927
# [434]	validation_0-mlogloss:0.96931
# [435]	validation_0-mlogloss:0.96940
# [436]	validation_0-mlogloss:0.96954
# [437]	validation_0-mlogloss:0.96971
# [438]	validation_0-mlogloss:0.96984
# [439]	validation_0-mlogloss:0.97000
# [440]	validation_0-mlogloss:0.96999
# [441]	validation_0-mlogloss:0.97007
# [442]	validation_0-mlogloss:0.97012
# [443]	validation_0-mlogloss:0.97019
# [444]	validation_0-mlogloss:0.97034
# [445]	validation_0-mlogloss:0.97042
# [446]	validation_0-mlogloss:0.97046
# [447]	validation_0-mlogloss:0.97043
# [448]	validation_0-mlogloss:0.97042
# [449]	validation_0-mlogloss:0.97045
# [450]	validation_0-mlogloss:0.97071
# [451]	validation_0-mlogloss:0.97089
# [452]	validation_0-mlogloss:0.97092
# [453]	validation_0-mlogloss:0.97116
# [454]	validation_0-mlogloss:0.97130
# [455]	validation_0-mlogloss:0.97131
# [456]	validation_0-mlogloss:0.97141
# [457]	validation_0-mlogloss:0.97152
# [458]	validation_0-mlogloss:0.97168
# [459]	validation_0-mlogloss:0.97168
# [460]	validation_0-mlogloss:0.97173
# [461]	validation_0-mlogloss:0.97177
# [462]	validation_0-mlogloss:0.97184
# [463]	validation_0-mlogloss:0.97195
# [464]	validation_0-mlogloss:0.97210
# [465]	validation_0-mlogloss:0.97218
# [466]	validation_0-mlogloss:0.97234
# [467]	validation_0-mlogloss:0.97231
# [468]	validation_0-mlogloss:0.97245
# [469]	validation_0-mlogloss:0.97246
# [470]	validation_0-mlogloss:0.97251
# [471]	validation_0-mlogloss:0.97258
# [472]	validation_0-mlogloss:0.97273
# [473]	validation_0-mlogloss:0.97282
# [474]	validation_0-mlogloss:0.97291
# [475]	validation_0-mlogloss:0.97313
# [476]	validation_0-mlogloss:0.97327
# [477]	validation_0-mlogloss:0.97338
# [478]	validation_0-mlogloss:0.97341
# [479]	validation_0-mlogloss:0.97353
# [480]	validation_0-mlogloss:0.97366
# [481]	validation_0-mlogloss:0.97380
# [482]	validation_0-mlogloss:0.97383
# [483]	validation_0-mlogloss:0.97399
# [484]	validation_0-mlogloss:0.97401
# [485]	validation_0-mlogloss:0.97401
# [486]	validation_0-mlogloss:0.97409
# [487]	validation_0-mlogloss:0.97428
# [488]	validation_0-mlogloss:0.97435
# [489]	validation_0-mlogloss:0.97446
# [490]	validation_0-mlogloss:0.97449
# [491]	validation_0-mlogloss:0.97445
# [492]	validation_0-mlogloss:0.97457
# [493]	validation_0-mlogloss:0.97477
# [494]	validation_0-mlogloss:0.97486
# [495]	validation_0-mlogloss:0.97500
# [496]	validation_0-mlogloss:0.97501
# [497]	validation_0-mlogloss:0.97517
# [498]	validation_0-mlogloss:0.97534
# [499]	validation_0-mlogloss:0.97542
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=10, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=500, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

y_pred = xgb.predict(X_test)

# to have classes labels instead of numbers
y_pred_labels = le.inverse_transform(y_pred)
y_test_labels = le.inverse_transform(y_test)

print(classification_report(y_test_labels, y_pred_labels))
accuracy = accuracy_score(y_test_labels, y_pred_labels)
print("Accuracy:", accuracy)
# Out:
#                      precision    recall  f1-score   support
#
#           Classical       0.85      0.79      0.82       246
#          Electronic       0.66      0.73      0.70      1874
#        Experimental       0.64      0.77      0.70      2122
#                Folk       0.67      0.64      0.65       561
#             Hip-Hop       0.75      0.69      0.72       710
#        Instrumental       0.51      0.29      0.37       416
#       International       0.80      0.46      0.58       278
#                Jazz       0.69      0.21      0.32       114
# Old-Time / Historic       0.95      0.94      0.94       111
#               Other       0.88      0.07      0.13       101
#                 Pop       0.49      0.16      0.24       466
#                Rock       0.77      0.86      0.81      2836
#              Spoken       0.75      0.49      0.60        85
#
#            accuracy                           0.70      9920
#           macro avg       0.72      0.55      0.58      9920
#        weighted avg       0.70      0.70      0.69      9920
#
# Accuracy: 0.7022177419354839

# %% [markdown]
# On constate que très vite la fonction de perte atteint un plancher autour de 0.95. Nous essayons donc d'utiliser de l'*early-stopping*. Même si les résultats sont légèrement moins bons, on diminue presque par deux la durée de l'entraînement ce qui constitue un gain de temps non négligeable.

# %%
xgb = XGBClassifier(
    max_depth=10,
    min_child_weight=10,
    eval_metric="mlogloss",
    learning_rate=0.1,
    n_estimators=1000,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    early_stopping_rounds=50
)

xgb.fit(
    X_train,y_train, eval_set=[(X_test,y_test)],
    verbose=True
)
# Out:
# [0]	validation_0-mlogloss:2.28201
# [1]	validation_0-mlogloss:2.14257
# [2]	validation_0-mlogloss:2.03104
# [3]	validation_0-mlogloss:1.93861
# [4]	validation_0-mlogloss:1.85974
# [5]	validation_0-mlogloss:1.79250
# [6]	validation_0-mlogloss:1.73262
# [7]	validation_0-mlogloss:1.67849
# [8]	validation_0-mlogloss:1.63115
# [9]	validation_0-mlogloss:1.58818
# [10]	validation_0-mlogloss:1.54960
# [11]	validation_0-mlogloss:1.51415
# [12]	validation_0-mlogloss:1.48186
# [13]	validation_0-mlogloss:1.45269
# [14]	validation_0-mlogloss:1.42605
# [15]	validation_0-mlogloss:1.40121
# [16]	validation_0-mlogloss:1.37756
# [17]	validation_0-mlogloss:1.35653
# [18]	validation_0-mlogloss:1.33690
# [19]	validation_0-mlogloss:1.31840
# [20]	validation_0-mlogloss:1.30130
# [21]	validation_0-mlogloss:1.28545
# [22]	validation_0-mlogloss:1.27039
# [23]	validation_0-mlogloss:1.25649
# [24]	validation_0-mlogloss:1.24344
# [25]	validation_0-mlogloss:1.23126
# [26]	validation_0-mlogloss:1.21963
# [27]	validation_0-mlogloss:1.20902
# [28]	validation_0-mlogloss:1.19933
# [29]	validation_0-mlogloss:1.18925
# [30]	validation_0-mlogloss:1.18006
# [31]	validation_0-mlogloss:1.17184
# [32]	validation_0-mlogloss:1.16379
# [33]	validation_0-mlogloss:1.15630
# [34]	validation_0-mlogloss:1.14884
# [35]	validation_0-mlogloss:1.14225
# [36]	validation_0-mlogloss:1.13623
# [37]	validation_0-mlogloss:1.12998
# [38]	validation_0-mlogloss:1.12437
# [39]	validation_0-mlogloss:1.11913
# [40]	validation_0-mlogloss:1.11388
# [41]	validation_0-mlogloss:1.10862
# [42]	validation_0-mlogloss:1.10367
# [43]	validation_0-mlogloss:1.09910
# [44]	validation_0-mlogloss:1.09465
# [45]	validation_0-mlogloss:1.09016
# [46]	validation_0-mlogloss:1.08593
# [47]	validation_0-mlogloss:1.08201
# [48]	validation_0-mlogloss:1.07822
# [49]	validation_0-mlogloss:1.07418
# [50]	validation_0-mlogloss:1.07056
# [51]	validation_0-mlogloss:1.06723
# [52]	validation_0-mlogloss:1.06416
# [53]	validation_0-mlogloss:1.06127
# [54]	validation_0-mlogloss:1.05849
# [55]	validation_0-mlogloss:1.05501
# [56]	validation_0-mlogloss:1.05231
# [57]	validation_0-mlogloss:1.04973
# [58]	validation_0-mlogloss:1.04723
# [59]	validation_0-mlogloss:1.04486
# [60]	validation_0-mlogloss:1.04238
# [61]	validation_0-mlogloss:1.04032
# [62]	validation_0-mlogloss:1.03829
# [63]	validation_0-mlogloss:1.03607
# [64]	validation_0-mlogloss:1.03393
# [65]	validation_0-mlogloss:1.03177
# [66]	validation_0-mlogloss:1.03005
# [67]	validation_0-mlogloss:1.02818
# [68]	validation_0-mlogloss:1.02616
# [69]	validation_0-mlogloss:1.02436
# [70]	validation_0-mlogloss:1.02259
# [71]	validation_0-mlogloss:1.02092
# [72]	validation_0-mlogloss:1.01930
# [73]	validation_0-mlogloss:1.01756
# [74]	validation_0-mlogloss:1.01586
# [75]	validation_0-mlogloss:1.01416
# [76]	validation_0-mlogloss:1.01262
# [77]	validation_0-mlogloss:1.01097
# [78]	validation_0-mlogloss:1.00959
# [79]	validation_0-mlogloss:1.00832
# [80]	validation_0-mlogloss:1.00700
# [81]	validation_0-mlogloss:1.00553
# [82]	validation_0-mlogloss:1.00409
# [83]	validation_0-mlogloss:1.00301
# [84]	validation_0-mlogloss:1.00214
# [85]	validation_0-mlogloss:1.00067
# [86]	validation_0-mlogloss:0.99992
# [87]	validation_0-mlogloss:0.99847
# [88]	validation_0-mlogloss:0.99729
# [89]	validation_0-mlogloss:0.99654
# [90]	validation_0-mlogloss:0.99547
# [91]	validation_0-mlogloss:0.99444
# [92]	validation_0-mlogloss:0.99329
# [93]	validation_0-mlogloss:0.99259
# [94]	validation_0-mlogloss:0.99160
# [95]	validation_0-mlogloss:0.99084
# [96]	validation_0-mlogloss:0.99005
# [97]	validation_0-mlogloss:0.98930
# [98]	validation_0-mlogloss:0.98851
# [99]	validation_0-mlogloss:0.98774
# [100]	validation_0-mlogloss:0.98702
# [101]	validation_0-mlogloss:0.98620
# [102]	validation_0-mlogloss:0.98543
# [103]	validation_0-mlogloss:0.98471
# [104]	validation_0-mlogloss:0.98404
# [105]	validation_0-mlogloss:0.98334
# [106]	validation_0-mlogloss:0.98256
# [107]	validation_0-mlogloss:0.98182
# [108]	validation_0-mlogloss:0.98099
# [109]	validation_0-mlogloss:0.98053
# [110]	validation_0-mlogloss:0.97988
# [111]	validation_0-mlogloss:0.97936
# [112]	validation_0-mlogloss:0.97880
# [113]	validation_0-mlogloss:0.97801
# [114]	validation_0-mlogloss:0.97738
# [115]	validation_0-mlogloss:0.97665
# [116]	validation_0-mlogloss:0.97607
# [117]	validation_0-mlogloss:0.97572
# [118]	validation_0-mlogloss:0.97533
# [119]	validation_0-mlogloss:0.97502
# [120]	validation_0-mlogloss:0.97472
# [121]	validation_0-mlogloss:0.97421
# [122]	validation_0-mlogloss:0.97387
# [123]	validation_0-mlogloss:0.97350
# [124]	validation_0-mlogloss:0.97303
# [125]	validation_0-mlogloss:0.97291
# [126]	validation_0-mlogloss:0.97239
# [127]	validation_0-mlogloss:0.97182
# [128]	validation_0-mlogloss:0.97160
# [129]	validation_0-mlogloss:0.97078
# [130]	validation_0-mlogloss:0.97046
# [131]	validation_0-mlogloss:0.96978
# [132]	validation_0-mlogloss:0.96929
# [133]	validation_0-mlogloss:0.96910
# [134]	validation_0-mlogloss:0.96885
# [135]	validation_0-mlogloss:0.96832
# [136]	validation_0-mlogloss:0.96778
# [137]	validation_0-mlogloss:0.96740
# [138]	validation_0-mlogloss:0.96699
# [139]	validation_0-mlogloss:0.96658
# [140]	validation_0-mlogloss:0.96632
# [141]	validation_0-mlogloss:0.96579
# [142]	validation_0-mlogloss:0.96532
# [143]	validation_0-mlogloss:0.96485
# [144]	validation_0-mlogloss:0.96450
# [145]	validation_0-mlogloss:0.96416
# [146]	validation_0-mlogloss:0.96386
# [147]	validation_0-mlogloss:0.96350
# [148]	validation_0-mlogloss:0.96338
# [149]	validation_0-mlogloss:0.96310
# [150]	validation_0-mlogloss:0.96286
# [151]	validation_0-mlogloss:0.96246
# [152]	validation_0-mlogloss:0.96220
# [153]	validation_0-mlogloss:0.96223
# [154]	validation_0-mlogloss:0.96190
# [155]	validation_0-mlogloss:0.96172
# [156]	validation_0-mlogloss:0.96151
# [157]	validation_0-mlogloss:0.96146
# [158]	validation_0-mlogloss:0.96122
# [159]	validation_0-mlogloss:0.96114
# [160]	validation_0-mlogloss:0.96082
# [161]	validation_0-mlogloss:0.96056
# [162]	validation_0-mlogloss:0.96052
# [163]	validation_0-mlogloss:0.96023
# [164]	validation_0-mlogloss:0.96033
# [165]	validation_0-mlogloss:0.96021
# [166]	validation_0-mlogloss:0.95991
# [167]	validation_0-mlogloss:0.95952
# [168]	validation_0-mlogloss:0.95931
# [169]	validation_0-mlogloss:0.95879
# [170]	validation_0-mlogloss:0.95855
# [171]	validation_0-mlogloss:0.95842
# [172]	validation_0-mlogloss:0.95794
# [173]	validation_0-mlogloss:0.95791
# [174]	validation_0-mlogloss:0.95780
# [175]	validation_0-mlogloss:0.95767
# [176]	validation_0-mlogloss:0.95745
# [177]	validation_0-mlogloss:0.95701
# [178]	validation_0-mlogloss:0.95679
# [179]	validation_0-mlogloss:0.95664
# [180]	validation_0-mlogloss:0.95655
# [181]	validation_0-mlogloss:0.95656
# [182]	validation_0-mlogloss:0.95632
# [183]	validation_0-mlogloss:0.95632
# [184]	validation_0-mlogloss:0.95633
# [185]	validation_0-mlogloss:0.95630
# [186]	validation_0-mlogloss:0.95626
# [187]	validation_0-mlogloss:0.95617
# [188]	validation_0-mlogloss:0.95626
# [189]	validation_0-mlogloss:0.95623
# [190]	validation_0-mlogloss:0.95640
# [191]	validation_0-mlogloss:0.95613
# [192]	validation_0-mlogloss:0.95608
# [193]	validation_0-mlogloss:0.95610
# [194]	validation_0-mlogloss:0.95601
# [195]	validation_0-mlogloss:0.95595
# [196]	validation_0-mlogloss:0.95585
# [197]	validation_0-mlogloss:0.95566
# [198]	validation_0-mlogloss:0.95554
# [199]	validation_0-mlogloss:0.95549
# [200]	validation_0-mlogloss:0.95566
# [201]	validation_0-mlogloss:0.95562
# [202]	validation_0-mlogloss:0.95556
# [203]	validation_0-mlogloss:0.95550
# [204]	validation_0-mlogloss:0.95542
# [205]	validation_0-mlogloss:0.95542
# [206]	validation_0-mlogloss:0.95551
# [207]	validation_0-mlogloss:0.95524
# [208]	validation_0-mlogloss:0.95530
# [209]	validation_0-mlogloss:0.95524
# [210]	validation_0-mlogloss:0.95502
# [211]	validation_0-mlogloss:0.95487
# [212]	validation_0-mlogloss:0.95479
# [213]	validation_0-mlogloss:0.95467
# [214]	validation_0-mlogloss:0.95460
# [215]	validation_0-mlogloss:0.95450
# [216]	validation_0-mlogloss:0.95461
# [217]	validation_0-mlogloss:0.95450
# [218]	validation_0-mlogloss:0.95455
# [219]	validation_0-mlogloss:0.95438
# [220]	validation_0-mlogloss:0.95424
# [221]	validation_0-mlogloss:0.95420
# [222]	validation_0-mlogloss:0.95424
# [223]	validation_0-mlogloss:0.95408
# [224]	validation_0-mlogloss:0.95401
# [225]	validation_0-mlogloss:0.95398
# [226]	validation_0-mlogloss:0.95412
# [227]	validation_0-mlogloss:0.95419
# [228]	validation_0-mlogloss:0.95429
# [229]	validation_0-mlogloss:0.95432
# [230]	validation_0-mlogloss:0.95429
# [231]	validation_0-mlogloss:0.95436
# [232]	validation_0-mlogloss:0.95426
# [233]	validation_0-mlogloss:0.95420
# [234]	validation_0-mlogloss:0.95429
# [235]	validation_0-mlogloss:0.95433
# [236]	validation_0-mlogloss:0.95434
# [237]	validation_0-mlogloss:0.95443
# [238]	validation_0-mlogloss:0.95448
# [239]	validation_0-mlogloss:0.95478
# [240]	validation_0-mlogloss:0.95489
# [241]	validation_0-mlogloss:0.95494
# [242]	validation_0-mlogloss:0.95497
# [243]	validation_0-mlogloss:0.95509
# [244]	validation_0-mlogloss:0.95498
# [245]	validation_0-mlogloss:0.95522
# [246]	validation_0-mlogloss:0.95518
# [247]	validation_0-mlogloss:0.95529
# [248]	validation_0-mlogloss:0.95525
# [249]	validation_0-mlogloss:0.95537
# [250]	validation_0-mlogloss:0.95544
# [251]	validation_0-mlogloss:0.95535
# [252]	validation_0-mlogloss:0.95519
# [253]	validation_0-mlogloss:0.95511
# [254]	validation_0-mlogloss:0.95502
# [255]	validation_0-mlogloss:0.95503
# [256]	validation_0-mlogloss:0.95503
# [257]	validation_0-mlogloss:0.95514
# [258]	validation_0-mlogloss:0.95520
# [259]	validation_0-mlogloss:0.95528
# [260]	validation_0-mlogloss:0.95531
# [261]	validation_0-mlogloss:0.95522
# [262]	validation_0-mlogloss:0.95535
# [263]	validation_0-mlogloss:0.95546
# [264]	validation_0-mlogloss:0.95564
# [265]	validation_0-mlogloss:0.95564
# [266]	validation_0-mlogloss:0.95553
# [267]	validation_0-mlogloss:0.95535
# [268]	validation_0-mlogloss:0.95529
# [269]	validation_0-mlogloss:0.95536
# [270]	validation_0-mlogloss:0.95545
# [271]	validation_0-mlogloss:0.95540
# [272]	validation_0-mlogloss:0.95542
# [273]	validation_0-mlogloss:0.95542
# [274]	validation_0-mlogloss:0.95545
# [275]	validation_0-mlogloss:0.95567
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=50,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=10, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=1000, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
y_pred = xgb.predict(X_test)

y_pred_labels = le.inverse_transform(y_pred)
y_test_labels = le.inverse_transform(y_test)

print(classification_report(y_test_labels, y_pred_labels))
accuracy = accuracy_score(y_test_labels, y_pred_labels)
print("Accuracy:", accuracy)
# Out:
#                      precision    recall  f1-score   support
#
#           Classical       0.86      0.78      0.82       246
#          Electronic       0.66      0.73      0.69      1874
#        Experimental       0.63      0.76      0.69      2122
#                Folk       0.67      0.62      0.64       561
#             Hip-Hop       0.75      0.68      0.72       710
#        Instrumental       0.50      0.28      0.36       416
#       International       0.79      0.42      0.55       278
#                Jazz       0.71      0.19      0.30       114
# Old-Time / Historic       0.94      0.93      0.93       111
#               Other       0.67      0.06      0.11       101
#                 Pop       0.48      0.16      0.24       466
#                Rock       0.76      0.85      0.80      2836
#              Spoken       0.67      0.46      0.55        85
#
#            accuracy                           0.69      9920
#           macro avg       0.70      0.53      0.57      9920
#        weighted avg       0.69      0.69      0.68      9920
#
# Accuracy: 0.6940524193548387

# %% [markdown]
# ## III. Optimisation des performances
#
# Comme pour la forêt aléatoire, ous tentons ici d'améliorer les performances du modèle en sélectionnant plus finement les *features* selon leur importance dans la prédiction.

# %%
importances = pd.Series(
    xgb.feature_importances_,
    index=X_train.columns
).sort_values(ascending=False)

# %% [markdown]
# Les *chroma STFT max* sont encore moins importantes que pour la forêt aléatoire mais les retirer ne change toujours que peu de choses aux résultats.

# %%
importances[280:]
# Out:
# mfcc_skew_17          0.001906
# mfcc_kurtosis_07      0.001901
# mfcc_skew_18          0.001889
# mfcc_kurtosis_12      0.001886
# mfcc_skew_19          0.001848
# tonnetz_skew_03       0.001828
# tonnetz_skew_04       0.001766
# tonnetz_skew_05       0.001726
# chroma_stft_max_03    0.000000
# chroma_stft_max_02    0.000000
# chroma_stft_max_01    0.000000
# chroma_stft_max_04    0.000000
# chroma_stft_max_08    0.000000
# chroma_stft_max_05    0.000000
# chroma_stft_max_06    0.000000
# chroma_stft_max_07    0.000000
# chroma_stft_max_12    0.000000
# chroma_stft_max_09    0.000000
# chroma_stft_max_10    0.000000
# chroma_stft_max_11    0.000000
# dtype: float32

# %% [markdown]
# On applique là encore un tri plus fin de l'importance des *features*.

# %%
from sklearn.inspection import permutation_importance

r = permutation_importance(
    xgb,
    X_test,
    y_test,
    n_repeats=5,
    scoring="f1_weighted",
    random_state=42
)

perm_importance = pd.Series(
    r.importances_mean,
    index=X_test.columns
).sort_values()

# %%
top_50_features=perm_importance[250:].index.tolist()
top_100_features=perm_importance[200:].index.tolist()
top_150_features=perm_importance[150:].index.tolist()

perm_importance
# Out:
# mfcc_skew_12                -0.000714
# mfcc_kurtosis_13            -0.000648
# chroma_stft_skew_05         -0.000637
# chroma_stft_skew_12         -0.000582
# chroma_stft_kurtosis_12     -0.000560
#                                ...
# spectral_contrast_skew_03    0.006253
# tonnetz_std_04               0.006720
# spectral_contrast_mean_04    0.007539
# spectral_contrast_mean_02    0.010918
# mfcc_max_04                  0.010977
# Length: 300, dtype: float64

# %% [markdown]
# Nous essayons comme pour la forêt aléatoire de nous en tenir à moins de *features* pour gagner en efficacité.

# %%
# 50 features
X=df_flat[top_50_features]
X_train_50, X_test_50, y_train_50, y_test_50 = train_test_split(X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)

# 100 features
X=df_flat[top_100_features]
X_train_100, X_test_100, y_train_100, y_test_100 = train_test_split(X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)

# 150 features
X=df_flat[top_150_features]
X_train_150, X_test_150, y_train_150, y_test_150 = train_test_split(X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)

# %% [markdown]
# L'observation faite pour la forêt aléatoire est encore plus vraie ici. Avec 150 *features* nous avons quasiment les mêmes résultats qu'avec le *dataframe* complet (0.690 contre 0.694 d'*accuracy*).

# %%
xgb = XGBClassifier(
    max_depth=10,
    min_child_weight=10,
    eval_metric="mlogloss",
    learning_rate=0.1,
    n_estimators=1000,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    early_stopping_rounds=50
)

xgb.fit(
    X_train_50,y_train_50, eval_set=[(X_test_50,y_test_50)],
    verbose=False # no print of the evaluation
)
y_pred_50 = xgb.predict(X_test_50)

xgb.fit(
    X_train_100,y_train_100, eval_set=[(X_test_100,y_test_100)],
    verbose=False
)
y_pred_100 = xgb.predict(X_test_100)

xgb.fit(
    X_train_150,y_train_150, eval_set=[(X_test_150,y_test_150)],
    verbose=False
)
y_pred_150 = xgb.predict(X_test_150)


print("Accuracy with top 50 features :", accuracy_score(y_test_50, y_pred_50))
print("Accuracy with top 100 features :", accuracy_score(y_test_100, y_pred_100))
print("Accuracy with top 150 features :", accuracy_score(y_test_150, y_pred_150))

y_pred_labels = le.inverse_transform(y_pred_150)
y_test_labels = le.inverse_transform(y_test_150)

print(classification_report(y_test_150, y_pred_150))
# Out:
# Accuracy with top 50 features : 0.6764112903225806
# Accuracy with top 100 features : 0.6895161290322581
# Accuracy with top 150 features : 0.6900201612903226
#               precision    recall  f1-score   support
#
#            0       0.85      0.79      0.82       246
#            1       0.66      0.72      0.69      1874
#            2       0.62      0.74      0.68      2122
#            3       0.67      0.62      0.65       561
#            4       0.74      0.68      0.71       710
#            5       0.52      0.32      0.40       416
#            6       0.81      0.42      0.56       278
#            7       0.71      0.19      0.30       114
#            8       0.94      0.92      0.93       111
#            9       0.62      0.05      0.09       101
#           10       0.47      0.15      0.23       466
#           11       0.76      0.85      0.80      2836
#           12       0.70      0.52      0.59        85
#
#     accuracy                           0.69      9920
#    macro avg       0.70      0.54      0.57      9920
# weighted avg       0.68      0.69      0.67      9920
